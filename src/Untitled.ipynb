# %%
from biothings_explorer import BioThingsExplorer

# %%
bt_explorer = BioThingsExplorer()

# %%
registry = bt_explorer.registry

# %%
registry.endpoint_info
# Out:
# {'http://mygene.info/v3/querygene': {'get': {'summary': 'Make gene query and return matching gene hits',
#    'parameters': [{'name': 'geneid',
#      'in': 'path',
#      'description': 'Query string. Examples "CDK2", "NM_052827", "204639_at". The detailed query syntax can be found at http://docs.mygene.info/en/latest/doc/query_service.html',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/hgnc.symbol/',
#       'http://identifiers.org/refseq/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/hgnc.symbol/',
#        'template': '/query?q=symbol:{geneid}&size=100'},
#       {'valueType': 'http://identifiers.org/refseq/',
#        'template': '/query?q=refseq.genomic:{geneid}&size=100'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': 'hits.entrezgene',
#        'valueType': 'http://identifiers.org/ncbigene/'},
#       {'path': 'hits.symbol',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'}],
#      'x-JSONLDContext': 'mygene.info/jsonld_context/mygene_query_object.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mygene.info/jsonld_context/mygene_query_object.json',
#   'output': ['http://identifiers.org/ncbigene/',
#    'http://identifiers.org/hgnc.symbol/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/ncbigene/': {'assoc:ThingToGeneAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/ThingToGeneAssociation'],
#   'input': ['http://identifiers.org/hgnc.symbol/',
#    'http://identifiers.org/refseq/'],
#   'api': 'MyGene.info API',
#   'server': 'http://mygene.info/v3'},
#  'http://mygene.info/v3/querygeneproduct': {'get': {'summary': 'Make gene query and return matching gene hits',
#    'parameters': [{'name': 'geneproductid',
#      'in': 'path',
#      'description': 'Query string. Examples "CDK2", "NM_052827", "204639_at". The detailed query syntax can be found at http://docs.mygene.info/en/latest/doc/query_service.html',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/unigene/',
#       'http://identifiers.org/uniprot/',
#       'http://identifiers.org/pdb/',
#       'http://biothings.io/explorer/vocab/terms/ensembl.protein/',
#       'http://biothings.io/explorer/vocab/terms/ensembl.transcript/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/unigene/',
#        'template': '/query?q=unigene:{geneproductid}&size=100'},
#       {'valueType': 'http://identifiers.org/uniprot/',
#        'template': '/query?q=uniprot.Swiss-Prot:{geneproductid}&size=100'},
#       {'valueType': 'http://identifiers.org/pdb/',
#        'template': '/query?q=pdb:{geneproductid}&size=100'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.protein/',
#        'template': '/query?q=ensembl.protein:{geneproductid}&size=100'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.transcript/',
#        'template': '/query?q=ensembl.transcript:{geneproductid}&size=100'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': 'hits.entrezgene',
#        'valueType': 'http://identifiers.org/ncbigene/'},
#       {'path': 'hits.symbol',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'}],
#      'x-JSONLDContext': 'mygene.info/jsonld_context/mygene_query_object.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mygene.info/jsonld_context/mygene_query_object.json',
#   'output': ['http://identifiers.org/ncbigene/',
#    'http://identifiers.org/hgnc.symbol/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/ncbigene/': {'assoc:ThingToGeneAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/ThingToGeneAssociation'],
#   'input': ['http://identifiers.org/unigene/',
#    'http://identifiers.org/uniprot/',
#    'http://identifiers.org/pdb/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.protein/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.transcript/'],
#   'api': 'MyGene.info API',
#   'server': 'http://mygene.info/v3'},
#  'http://mygene.info/v3/querypathway': {'get': {'summary': 'Make gene query and return matching gene hits',
#    'parameters': [{'name': 'pathwayid',
#      'in': 'path',
#      'description': 'Query string. Examples "CDK2", "NM_052827", "204639_at". The detailed query syntax can be found at http://docs.mygene.info/en/latest/doc/query_service.html',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/biocarta.pathway/',
#       'http://identifiers.org/kegg.pathway/',
#       'http://identifiers.org/wikipathways/',
#       'http://identifiers.org/pharmgkb.pathways/',
#       'http://biothings.io/explorer/vocab/terms/reactome.pathway/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/biocarta.pathway/',
#        'template': '/query?q=pathway.biocarta.id:{pathwayid}&size=100'},
#       {'valueType': 'http://identifiers.org/kegg.pathway/',
#        'template': '/query?q=pathway.kegg.id:{pathwayid}&size=100'},
#       {'valueType': 'http://identifiers.org/wikipathways/',
#        'template': '/query?q=pathway.wikipathways.id:{pathwayid}&size=100'},
#       {'valueType': 'http://identifiers.org/pharmgkb.pathways/',
#        'template': '/query?q=pathway.pharmgkb.id:{pathwayid}&size=100'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/reactome.pathway/',
#        'template': '/query?q=pathway.reactome.id:{pathwayid}&size=100'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': 'hits.entrezgene',
#        'valueType': 'http://identifiers.org/ncbigene/'},
#       {'path': 'hits.symbol',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'}],
#      'x-JSONLDContext': 'mygene.info/jsonld_context/mygene_query_pathway.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mygene.info/jsonld_context/mygene_query_pathway.json',
#   'output': ['http://identifiers.org/ncbigene/',
#    'http://identifiers.org/hgnc.symbol/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/ncbigene/': {'assoc:PathwayToGeneAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/PathwayToGeneAssociation'],
#   'input': ['http://identifiers.org/biocarta.pathway/',
#    'http://identifiers.org/kegg.pathway/',
#    'http://identifiers.org/wikipathways/',
#    'http://identifiers.org/pharmgkb.pathways/',
#    'http://biothings.io/explorer/vocab/terms/reactome.pathway/'],
#   'api': 'MyGene.info API',
#   'server': 'http://mygene.info/v3'},
#  'http://mygene.info/v3/querygo': {'get': {'summary': 'Make gene query and return matching gene hits',
#    'parameters': [{'name': 'goid',
#      'in': 'path',
#      'description': 'Query string. Examples "CDK2", "NM_052827", "204639_at". The detailed query syntax can be found at http://docs.mygene.info/en/latest/doc/query_service.html',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/go/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/go/',
#        'template': '/query?q=GO:{goid}&size=500'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': 'hits.entrezgene',
#        'valueType': 'http://identifiers.org/ncbigene/'},
#       {'path': 'hits.symbol',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'}],
#      'x-JSONLDContext': 'mygene.info/jsonld_context/mygene_query_pathway.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mygene.info/jsonld_context/mygene_query_pathway.json',
#   'output': ['http://identifiers.org/ncbigene/',
#    'http://identifiers.org/hgnc.symbol/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/ncbigene/': {'assoc:PathwayToGeneAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/PathwayToGeneAssociation'],
#   'input': ['http://identifiers.org/go/'],
#   'api': 'MyGene.info API',
#   'server': 'http://mygene.info/v3'},
#  'http://mygene.info/v3/gene/{geneid}': {'get': {'summary': 'For a given gene id, return the matching gene object',
#    'parameters': [{'name': 'geneid',
#      'in': 'path',
#      'description': 'Entrez or Ensembl gene id, e.g., 1017, ENSG00000170248. A retired Entrez Gene id works too if it is replaced by a new one, e.g., 245794',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/ncbigene/',
#       'http://biothings.io/explorer/vocab/terms/ensembl.gene/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/ncbigene/',
#        'template': '/gene/{geneid}'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.gene/',
#        'template': '/gene/{geneid}'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A gene object',
#      'x-responseValueType': [{'path': 'symbol',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'},
#       {'path': 'umls.cui',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.gene/'},
#       {'path': 'unigene', 'valueType': 'http://identifiers.org/unigene/'},
#       {'path': 'uniprot.Swiss-Prot',
#        'valueType': 'http://identifiers.org/uniprot/'},
#       {'path': 'pdb', 'valueType': 'http://identifiers.org/pdb/'},
#       {'path': 'pathway.biocarta.id',
#        'valueType': 'http://identifiers.org/biocarta.pathway/'},
#       {'path': 'pathway.kegg.id',
#        'valueType': 'http://identifiers.org/kegg.pathway/'},
#       {'path': 'pathway.reactome.id',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/reactome.pathway/'},
#       {'path': 'pathway.wikipathways.id',
#        'valueType': 'http://identifiers.org/wikipathways/'},
#       {'path': 'pathway.pharmgkb.id',
#        'valueType': 'http://identifiers.org/pharmgkb.pathways/'},
#       {'path': 'go.bp.id', 'valueType': 'http://identifiers.org/go/'},
#       {'path': 'ensembl.gene',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.gene/'},
#       {'path': 'ensembl.protein',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.protein/'},
#       {'path': 'ensembl.transcript',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.transcript/'},
#       {'path': 'MIM',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/omim.gene/'},
#       {'path': 'HGNC', 'valueType': 'http://identifiers.org/hgnc/'},
#       {'path': 'miRBase', 'valueType': 'http://identifiers.org/mirbase/'}],
#      'x-JSONLDContext': 'mygene.info/jsonld_context/mygene_gene_object.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mygene.info/jsonld_context/mygene_gene_object.json',
#   'output': ['http://identifiers.org/hgnc.symbol/',
#    'http://biothings.io/explorer/vocab/terms/umls.gene/',
#    'http://identifiers.org/unigene/',
#    'http://identifiers.org/uniprot/',
#    'http://identifiers.org/pdb/',
#    'http://identifiers.org/biocarta.pathway/',
#    'http://identifiers.org/kegg.pathway/',
#    'http://biothings.io/explorer/vocab/terms/reactome.pathway/',
#    'http://identifiers.org/wikipathways/',
#    'http://identifiers.org/pharmgkb.pathways/',
#    'http://identifiers.org/go/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.gene/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.protein/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.transcript/',
#    'http://biothings.io/explorer/vocab/terms/omim.gene/',
#    'http://identifiers.org/hgnc/',
#    'http://identifiers.org/mirbase/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/biocarta.pathway/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation'},
#                'http://identifiers.org/kegg.pathway/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation'},
#                'http://biothings.io/explorer/vocab/terms/reactome.pathway/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation'},
#                'http://identifiers.org/wikipathways/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation'},
#                'http://identifiers.org/pharmgkb.pathways/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation'},
#                'http://identifiers.org/uniprot/': {'assoc:GeneToGeneProductAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.gene/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/ensembl.protein/': {'assoc:GeneToGeneProductAssociation'},
#                'http://biothings.io/explorer/vocab/terms/ensembl.gene/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/ensembl.transcript/': {'assoc:GeneToGeneProductAssociation'},
#                'http://identifiers.org/go/': {'assoc:MacromolecularMachineToBiologicalProcessAssociation',
#                 'assoc:MacromolecularMachineToCellularComponentAssociation',
#                 'assoc:MacromolecularMachineToMolecularActivityAssociation'},
#                'http://identifiers.org/pdb/': {'assoc:GeneToProteinStructureAssociation'},
#                'http://identifiers.org/unigene/': {'assoc:GeneToGeneProductAssociation'},
#                'http://identifiers.org/hgnc.symbol/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/omim.gene/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/hgnc/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/mirbase/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/gene-description/': {'assoc:HasDescriptionAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/GeneToProteinStructureAssociation',
#    'http://biothings.io/explorer/vocab/objects/MacromolecularMachineToBiologicalProcessAssociation',
#    'http://biothings.io/explorer/vocab/objects/MacromolecularMachineToCellularComponentAssociation',
#    'http://biothings.io/explorer/vocab/objects/MacromolecularMachineToMolecularActivityAssociation',
#    'http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/HasDescriptionAssociation',
#    'http://biothings.io/explorer/vocab/objects/GeneToGeneProductAssociation'],
#   'input': ['http://identifiers.org/ncbigene/',
#    'http://biothings.io/explorer/vocab/terms/ensembl.gene/'],
#   'api': 'MyGene.info API',
#   'server': 'http://mygene.info/v3'},
#  'http://MyChem.info/v1/querybydrugtarget': {'get': {'summary': 'Query for chemicals which interacts with proteins',
#    'parameters': [{'name': 'uniprotid',
#      'in': 'path',
#      'description': 'Query string.',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/uniprot/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/uniprot/',
#        'template': '/query?q=drugbank.targets.uniprot:{uniprotid} OR drugcentral.bioactivity.uniprot_id:{uniprotid} OR pharmgkb.cross_references.uniprotkb:{uniprotid} & fields=_id'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': '_id',
#        'valueType': 'http://identifiers.org/inchikey/'}],
#      'x-JSONLDContext': 'mychem.info/jsonld_context/mychem_querybydrugtarget.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mychem.info/jsonld_context/mychem_querybydrugtarget.json',
#   'output': ['http://identifiers.org/inchikey/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/inchikey/': {'assoc:GeneOrGeneProductToChemicalAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/GeneOrGeneProductToChemicalAssociation'],
#   'input': ['http://identifiers.org/uniprot/'],
#   'api': 'MyChem.info API',
#   'server': 'http://MyChem.info/v1'},
#  'http://MyChem.info/v1/querybydiseaseid': {'get': {'summary': 'Query disease to chemical',
#    'parameters': [{'name': 'diseaseid',
#      'in': 'path',
#      'description': 'Query string. Examples "Fludara", "CHEMBI:63599", "DB01073".',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/snomedct/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/snomedct/',
#        'template': '/query?q=drugcentral.drug_use.snomed_id:{diseaseid}&fields=_id'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': '_id',
#        'valueType': 'http://identifiers.org/inchikey/'}],
#      'x-JSONLDContext': 'mychem.info/jsonld_context/mychem_query_disease2chemical.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mychem.info/jsonld_context/mychem_query_disease2chemical.json',
#   'output': ['http://identifiers.org/inchikey/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/inchikey/': {'assoc:DiseaseToChemicalAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/DiseaseToChemicalAssociation'],
#   'input': ['http://identifiers.org/snomedct/'],
#   'api': 'MyChem.info API',
#   'server': 'http://MyChem.info/v1'},
#  'http://MyChem.info/v1/querybydrugid': {'get': {'summary': 'Make chemical query and return matching chemical hits',
#    'parameters': [{'name': 'drugid',
#      'in': 'path',
#      'description': 'Query string. Examples "Fludara", "CHEMBI:63599", "DB01073".',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/rxcui/',
#       'http://identifiers.org/chebi/',
#       'http://identifiers.org/chembl.compound/',
#       'http://identifiers.org/drugbank/',
#       'http://identifiers.org/iuphar.ligand/',
#       'http://identifiers.org/kegg.drug/',
#       'http://identifiers.org/kegg.compound/',
#       'http://identifiers.org/pubchem.compound/',
#       'http://identifiers.org/unii/',
#       'http://identifiers.org/inchi/',
#       'http://biothings.io/explorer/vocab/terms/drug-name/',
#       'http://identifiers.org/pharmgkb.drug/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/rxcui/',
#        'template': 'aeolus.rxcui:input_value OR drugcentral.xref.rxnorm:input_value OR ginas.xrefs.RXCUI:input_value OR pharmgkb.external_vocabulary.rxnorm:input_value'},
#       {'valueType': 'http://identifiers.org/chebi/',
#        'template': 'drugcentral.xref.chebi:input_value OR chebi.chebi_id:input_value'},
#       {'valueType': 'http://identifiers.org/chembl.compound/',
#        'template': '/query?q=chembl.molecule_chembl_id:{drugid} OR drugbank.chembl:{drugid} OR drugcentral.xref.chembl_id:{drugid}&fields=drugcentral,drugbank,chembl'},
#       {'valueType': 'http://identifiers.org/drugbank/',
#        'template': '/query?q=drugcentral.xref.drugbank_id:{drugid} OR pharmgkb.cross_references.drugbank:{drugid} OR drugbank.drugbank_id:{drugid} OR chebi.drugbank_database_links:{drugid}'},
#       {'valueType': 'http://identifiers.org/iuphar.ligand/',
#        'template': 'drugcentral.xref.iuphar_ligand_id:input_value OR pharmgkb.cross_references.iuphar_ligand:input_value'},
#       {'valueType': 'http://identifiers.org/kegg.drug/',
#        'template': 'drugcentral.xref.kegg_drug:input_value OR chebi.kegg_drug_database_links:input_value OR drugbank.kegg_drug:input_value OR pharmgkb.cross_references.kegg_drug:input_value'},
#       {'valueType': 'http://identifiers.org/kegg.compound/',
#        'template': 'chebi.kegg_compound_database_links:input_value OR pharmgkb.cross_references.kegg_compound:input_value'},
#       {'valueType': 'http://identifiers.org/pubchem.compound/',
#        'template': 'drugcentral.xref.pubchem_cid:input_value OR chebi.pubchem_database_links:input_value OR pharmgkb.cross_references.pubchem_compound:input_value OR pubchem.cid:input_value'},
#       {'valueType': 'http://identifiers.org/unii/',
#        'template': 'drugcentral.xref.unii:input_value OR aeolus.unii:input_value OR ginas.unii:input_value OR unii.unii:input_value'},
#       {'valueType': 'http://identifiers.org/inchikey/',
#        'template': 'aeolus.inchikey:input_value OR chebi.inchikey:input_value OR chembl.inchi_key:input_value OR drugbank.inchi_key:input_value OR drugcentral.structures.inchikey:input_value OR ginas.inchikey:input_value OR pubchem.inchi_key:input_value OR unii.inchikey:input_value'},
#       {'valueType': 'http://identifiers.org/inchi/',
#        'template': 'pubchem.inchi:input_value OR pharmgkb.inchi:input_value OR drugcentral.structures.inchi:input_value OR drugbank.inchi:input_value OR chembl.inchi:input_value OR chebi.inchi:input_value'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/drug-name/',
#        'template': 'aeolus.drug_name:input_value OR chebi.chebi_name:input_value OR chembl.pref_name:input_value OR drugbank.name:input_value & fields=drugcentral, chebi, drugbank'},
#       {'valueType': 'http://identifiers.org/pharmgkb.drug/',
#        'template': 'pharmgkb.pharmgkb_accession_id:input_value'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A query response object with "hits" property',
#      'x-responseValueType': [{'path': '_id',
#        'valueType': 'http://identifiers.org/inchikey/'},
#       {'path': 'aeolus.drug_name',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/drug-name/'},
#       {'path': 'drugbank.accession_number',
#        'valueType': 'http://identifiers.org/drugbank/'},
#       {'path': 'chembl',
#        'valueType': 'http://identifiers.org/chembl.compound/'},
#       {'path': 'pubchem',
#        'valueType': 'http://identifiers.org/pubchem.compound/'},
#       {'path': 'drugbank.target.uniprot',
#        'valueType': 'http://identifiers.org/uniprot/'},
#       {'path': 'drugcentral.xref.umls',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.compound/'},
#       {'path': 'drugcentral.xref.mesh',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/mesh.compound/'},
#       {'path': 'chebi.definition',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/chemical-description/'},
#       {'path': 'drugcentral.drug_use.indication.snomed_id',
#        'valueType': 'http://identifiers.org/snomedct/'},
#       {'path': 'drugcentral.drug_use.indication.umls_cui',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/'},
#       {'path': 'drugcentral.drug_use.indication.concept_name',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/disease-name/'},
#       {'path': 'drugcental.fda_adverse_event.meddra_code',
#        'valueType': 'http://identifiers.org/meddra/'},
#       {'path': 'drugcentral.pharmacology_class.fda_epc.code',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/ndfrt/'},
#       {'path': 'chembl.max_phase',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/drug-phase/'}],
#      'x-JSONLDContext': 'mychem.info/jsonld_context/mychem_query_object.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mychem.info/jsonld_context/mychem_query_object.json',
#   'output': ['http://identifiers.org/inchikey/',
#    'http://biothings.io/explorer/vocab/terms/drug-name/',
#    'http://identifiers.org/drugbank/',
#    'http://identifiers.org/chembl.compound/',
#    'http://identifiers.org/pubchem.compound/',
#    'http://identifiers.org/uniprot/',
#    'http://biothings.io/explorer/vocab/terms/umls.compound/',
#    'http://biothings.io/explorer/vocab/terms/mesh.compound/',
#    'http://biothings.io/explorer/vocab/terms/chemical-description/',
#    'http://identifiers.org/snomedct/',
#    'http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://biothings.io/explorer/vocab/terms/disease-name/',
#    'http://identifiers.org/meddra/',
#    'http://biothings.io/explorer/vocab/terms/ndfrt/',
#    'http://biothings.io/explorer/vocab/terms/drug-phase/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/inchikey/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/rxcui/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/chembl.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/chebi/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/drugbank/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/iuphar.ligand/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/kegg.drug/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/pubchem.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/unii/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/mesh.compound/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/inchi/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.disease/': {'assoc:Treats'},
#                'http://identifiers.org/meddra/': {'assoc:Causes'},
#                'http://biothings.io/explorer/vocab/terms/ndfrt/': {'assoc:Subclass_of'},
#                'http://identifiers.org/pharmgkb.drug/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/kegg.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/pubchem.substance/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/clinicaltrials/': {'assoc:ChemicalToClinicalTrialAssociation'},
#                'http://biothings.io/explorer/vocab/terms/drug-name/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/chemical-description/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/uniprot/': {'assoc:Regulates'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/Regulates',
#    'http://biothings.io/explorer/vocab/objects/Subclass_of',
#    'http://biothings.io/explorer/vocab/objects/ChemicalToClinicalTrialAssociation',
#    'http://biothings.io/explorer/vocab/objects/Treats',
#    'http://biothings.io/explorer/vocab/objects/Causes'],
#   'input': ['http://biothings.io/explorer/vocab/terms/rxcui/',
#    'http://identifiers.org/chebi/',
#    'http://identifiers.org/chembl.compound/',
#    'http://identifiers.org/drugbank/',
#    'http://identifiers.org/iuphar.ligand/',
#    'http://identifiers.org/kegg.drug/',
#    'http://identifiers.org/kegg.compound/',
#    'http://identifiers.org/pubchem.compound/',
#    'http://identifiers.org/unii/',
#    'http://identifiers.org/inchi/',
#    'http://biothings.io/explorer/vocab/terms/drug-name/',
#    'http://identifiers.org/pharmgkb.drug/'],
#   'api': 'MyChem.info API',
#   'server': 'http://MyChem.info/v1'},
#  'http://MyChem.info/v1/drug/{drugid}': {'get': {'tags': ['chemical'],
#    'summary': 'Retrieve chemical objects based on ID',
#    'parameters': [{'name': 'drugid',
#      'in': 'path',
#      'description': 'DrugBank ID, InCHIKey, CHEBI ID, CHEMBL ID',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/inchikey/',
#       'http://identifiers.org/drugbank/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/inchikey/',
#        'template': '/drug/{drugid}'},
#       {'valueType': 'http://identifiers.org/drugbank/',
#        'template': '/drug/{drugid}'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching chemical object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': '_id',
#        'valueType': 'http://identifiers.org/inchikey/'},
#       {'path': 'aeolus.drugname',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/drug-name/'},
#       {'path': 'pubchem.inchi', 'valueType': 'http://identifiers.org/inchi/'},
#       {'path': 'drugcentral.xref.unii',
#        'valueType': 'http://identifiers.org/unii/'},
#       {'path': 'drugbank.enzymes.uniprot',
#        'valueType': 'http://identifiers.org/uniprot/'},
#       {'path': 'drugbank.drugbank_id',
#        'valueType': 'http://identifiers.org/drugbank/'},
#       {'path': 'cadd.gene.gene_id',
#        'valueType': 'http://identifiers.org/dbsnp/'},
#       {'path': 'cadd.gene.feature_id',
#        'valueType': 'http://identifiers.org/pubmed/'},
#       {'path': 'cadd.gene.ccds_id',
#        'valueType': 'http://identifiers.org/clinicaltrials/'},
#       {'path': 'aeolus.rxcui',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/rxcui/'},
#       {'path': 'chebi.chebi_id', 'valueType': 'http://identifiers.org/chebi/'},
#       {'path': 'chembl.molecule_chembl_id',
#        'valueType': 'http://identifiers.org/chembl.compound/'},
#       {'path': 'drugcentral.xref.kegg_drug',
#        'valueType': 'http://identifiers.org/kegg.drug/'},
#       {'path': 'chebi.kegg_compound_database_links',
#        'valueType': 'http://identifiers.org/kegg.compound/'},
#       {'path': 'drugcentral.drug_use.indication.snomed_id',
#        'valueType': 'http://identifiers.org/snomedct/'},
#       {'path': 'drugcentral.drug_use.indication.umls_cui',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/'},
#       {'path': 'drugcentral.xref.iuphar_ligand_id',
#        'valueType': 'http://identifiers.org/iuphar.ligand/'},
#       {'path': 'drugcentral.drug_use.indication.concept_name',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/disease-name/'},
#       {'path': 'pharmgkb.pharmgkb_accession_id',
#        'valueType': 'http://identifiers.org/pharmgkb.drug/'},
#       {'path': 'drugcentral.xref.pubchem_cid',
#        'valueType': 'http://identifiers.org/pubchem.compound/'},
#       {'path': 'pharmgkb.cross_references.pubchem_substance',
#        'valueType': 'http://identifiers.org/pubchem.substance/'},
#       {'path': 'drugcentral.xref.umls',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.compound/'},
#       {'path': 'drugcentral.xref.mesh',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/mesh.compound/'},
#       {'path': 'chebi.definition',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/chemical-description/'}],
#      'x-JSONLDContext': 'mychem.info/jsonld_context/mychem_drug_object.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mychem.info/jsonld_context/mychem_drug_object.json',
#   'output': ['http://identifiers.org/inchikey/',
#    'http://biothings.io/explorer/vocab/terms/drug-name/',
#    'http://identifiers.org/inchi/',
#    'http://identifiers.org/unii/',
#    'http://identifiers.org/uniprot/',
#    'http://identifiers.org/drugbank/',
#    'http://identifiers.org/dbsnp/',
#    'http://identifiers.org/pubmed/',
#    'http://identifiers.org/clinicaltrials/',
#    'http://biothings.io/explorer/vocab/terms/rxcui/',
#    'http://identifiers.org/chebi/',
#    'http://identifiers.org/chembl.compound/',
#    'http://identifiers.org/kegg.drug/',
#    'http://identifiers.org/kegg.compound/',
#    'http://identifiers.org/snomedct/',
#    'http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://identifiers.org/iuphar.ligand/',
#    'http://biothings.io/explorer/vocab/terms/disease-name/',
#    'http://identifiers.org/pharmgkb.drug/',
#    'http://identifiers.org/pubchem.compound/',
#    'http://identifiers.org/pubchem.substance/',
#    'http://biothings.io/explorer/vocab/terms/umls.compound/',
#    'http://biothings.io/explorer/vocab/terms/mesh.compound/',
#    'http://biothings.io/explorer/vocab/terms/chemical-description/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/inchikey/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/drug-name/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/rxcui/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/chebi/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/chembl.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/drugbank/': {'assoc:EquivalentAssociation',
#                 'assoc:PairwiseChemicalInteractionAssociation'},
#                'http://identifiers.org/iuphar.ligand/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/kegg.drug/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/pubchem.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/unii/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/mesh.compound/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/inchi/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.disease/': {'assoc:treats'},
#                'http://identifiers.org/pharmgkb.drug/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/kegg.compound/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/pubchem.substance/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/chemical-description/': {'assoc:HasDescriptionAssociation'},
#                'http://identifiers.org/uniprot/': {'assoc:ChemicalToGeneOrGeneProductAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/PairwiseChemicalInteractionAssociation',
#    'http://biothings.io/explorer/vocab/objects/treats',
#    'http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/HasDescriptionAssociation',
#    'http://biothings.io/explorer/vocab/objects/ChemicalToGeneOrGeneProductAssociation'],
#   'input': ['http://identifiers.org/inchikey/',
#    'http://identifiers.org/drugbank/'],
#   'api': 'MyChem.info API',
#   'server': 'http://MyChem.info/v1'},
#  'http://mydisease.info/v1/disease/{mondoid}': {'get': {'summary': 'Retrieve disease objects based on mondo ID',
#    'parameters': [{'name': 'mondoid',
#      'in': 'path',
#      'description': 'MONDO ID',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/mondo/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/mondo/',
#        'template': '/disease/MONDO:{mondoid}'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching disease object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'mondo.label',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/disease-name/'},
#       {'path': 'mondo.definition',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/disease-description/'},
#       {'path': 'mondo.xrefs.doid',
#        'valueType': 'http://identifiers.org/doid/'},
#       {'path': 'mondo.xrefs.omim',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/'},
#       {'path': 'mondo.xrefs.umls',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_disease_annotation.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_disease_annotation.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/disease-name/',
#    'http://biothings.io/explorer/vocab/terms/disease-description/',
#    'http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/',
#    'http://biothings.io/explorer/vocab/terms/umls.disease/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/doid/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/omim.disease/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/umls.disease/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/disease-name/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/disease-description/': {'assoc:HasDescriptionAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/HasDescriptionAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/mondo/'],
#   'api': 'MyDisease.info API',
#   'server': 'http://mydisease.info/v1'},
#  'http://mydisease.info/v1/querydiseasetogene': {'get': {'summary': 'Retrieve genes related to disease',
#    'parameters': [{'name': 'diseaseid',
#      'in': 'path',
#      'description': 'disease ID, e.g. UMLS ID',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#       'http://biothings.io/explorer/vocab/terms/mondo/',
#       'http://identifiers.org/doid/',
#       'http://biothings.io/explorer/vocab/terms/omim.disease/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/',
#        'template': '/query?q=disgenet.xrefs.umls:{diseaseid}&fields=disgenet.genes_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/mondo/',
#        'template': '/query?q=_id:"MONDO:{diseaseid}"&fields=disgenet.genes_related_to_disease'},
#       {'valueType': 'http://identifiers.org/doid/',
#        'template': '/query?q=mondo.xrefs.doid:"DOID:{diseaseid}"&fields=disgenet.genes_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/',
#        'template': '/query?q=mondo.xrefs.omim:{diseaseid}&fields=disgenet.genes_related_to_disease'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching gene object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'hits.disgenet.genes_related_to_disease.gene_id',
#        'valueType': 'http://identifiers.org/ncbigene/'},
#       {'path': 'hits.disgenet.genes_related_to_disease.gene_name',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_disease2gene.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_disease2gene.json',
#   'output': ['http://identifiers.org/ncbigene/',
#    'http://identifiers.org/hgnc.symbol/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/ncbigene/': {'assoc:DiseaseToGeneOrGeneProductAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/DiseaseToGeneOrGeneProductAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://biothings.io/explorer/vocab/terms/mondo/',
#    'http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/'],
#   'api': 'MyDisease.info API',
#   'server': 'http://mydisease.info/v1'},
#  'http://mydisease.info/v1/querydiseasetovariant': {'get': {'summary': 'Retrieve variants related to disease',
#    'parameters': [{'name': 'diseaseid',
#      'in': 'path',
#      'description': 'disease ID, e.g. UMLS ID',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#       'http://biothings.io/explorer/vocab/terms/mondo/',
#       'http://identifiers.org/doid/',
#       'http://biothings.io/explorer/vocab/terms/omim.disease/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/',
#        'template': '/query?q=disgenet.xrefs.umls:{diseaseid}&fields=disgenet.variants_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/mondo/',
#        'template': '/query?q=_id:"MONDO:{diseaseid}"&fields=disgenet.variants_related_to_disease'},
#       {'valueType': 'http://identifiers.org/doid/',
#        'template': '/query?q=mondo.xrefs.doid:"DOID:{diseaseid}"&fields=disgenet.variants_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/',
#        'template': '/query?q=mondo.xrefs.omim:{diseaseid}&fields=disgenet.variants_related_to_disease'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching gene object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'hits.disgenet.variants_related_to_disease.rsid',
#        'valueType': 'http://identifiers.org/dbsnp/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_disease2variant.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_disease2variant.json',
#   'output': ['http://identifiers.org/dbsnp/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/dbsnp/': {'assoc:DiseaseToVariantAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/DiseaseToVariantAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://biothings.io/explorer/vocab/terms/mondo/',
#    'http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/'],
#   'api': 'MyDisease.info API',
#   'server': 'http://mydisease.info/v1'},
#  'http://mydisease.info/v1/querydiseasetophenotype': {'get': {'summary': 'Retrieve phenotypes related to disease',
#    'parameters': [{'name': 'diseaseid',
#      'in': 'path',
#      'description': 'disease ID, e.g. UMLS ID',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#       'http://biothings.io/explorer/vocab/terms/mondo/',
#       'http://identifiers.org/doid/',
#       'http://biothings.io/explorer/vocab/terms/omim.disease/',
#       'http://identifiers.org/orphanet/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/',
#        'template': '/query?q=mondo.xrefs.umls:{diseaseid}&fields=hpo.phenotype_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/mondo/',
#        'template': '/query?q=_id:"MONDO:{diseaseid}"&fields=hpo.phenotype_related_to_disease'},
#       {'valueType': 'http://identifiers.org/doid/',
#        'template': '/query?q=mondo.xrefs.doid:"DOID:{diseaseid}"&fields=hpo.phenotype_related_to_disease'},
#       {'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/',
#        'template': '/query?q=mondo.xrefs.omim:{diseaseid}&fields=hpo.phenotype_related_to_disease'},
#       {'valueType': 'http://identifiers.org/orphanet/',
#        'template': '/query?q=mondo.xrefs.orphanet:{diseaseid}&fields=hpo.phenotype_related_to_disease'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching gene object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'hits.hpo.phenotypes_related_to_disease.rsid',
#        'valueType': 'http://identifiers.org/hp/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_disease2phenotype.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_disease2phenotype.json',
#   'output': ['http://identifiers.org/hp/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/hp/': {'assoc:DiseaseToPhenotypicFeatureAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/DiseaseToPhenotypicFeatureAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://biothings.io/explorer/vocab/terms/mondo/',
#    'http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/',
#    'http://identifiers.org/orphanet/'],
#   'api': 'MyDisease.info API',
#   'server': 'http://mydisease.info/v1'},
#  'http://mydisease.info/v1/queryphenotypetodisease': {'get': {'summary': 'Retrieve diseases related to phenotype',
#    'parameters': [{'name': 'phenotypeid',
#      'in': 'path',
#      'description': 'phenotype ID, e.g. HPO ID',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/hp/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/hp/',
#        'template': '/query?q=hpo.phenotype_related_to_disease.hpo_id:"HP:{phenotypeid}"&fields=_id,mondo'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching disease object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'hits.mondo.xrefs.doid',
#        'valueType': 'http://identifiers.org/doid/'},
#       {'path': 'hits.mondo.xrefs.omim',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_phenotype2disease.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_phenotype2disease.json',
#   'output': ['http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/doid/': {'assoc:PhenotypicFeatureToDiseaseAssociation'},
#                'http://biothings.io/explorer/vocab/terms/omim.disease/': {'assoc:PhenotypicFeatureToDiseaseAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/PhenotypicFeatureToDiseaseAssociation'],
#   'input': ['http://identifiers.org/hp/'],
#   'api': 'MyDisease.info API',
#   'server': 'http://mydisease.info/v1'},
#  'http://mydisease.info/v1/querygenetodisease': {'get': {'summary': 'Retrieve diseases related to phenotype',
#    'parameters': [{'name': 'geneid',
#      'in': 'path',
#      'description': 'gene ID, e.g. ncbigene id',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/ncbigene/',
#       'http://identifiers.org/hgnc.symbol/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/ncbigene/',
#        'template': '/query?q=disgenet.genes_related_to_disease.gene_id:{geneid}&fields=_id,mondo'},
#       {'valueType': 'http://identifiers.org/hgnc.symbol/',
#        'template': '/query?q=disgenet.genes_related_to_disease.gene_name:{geneid}&fields=_id,mondo'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A matching disease object',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Chem'}}},
#      'x-responseValueType': [{'path': 'hits.mondo.xrefs.doid',
#        'valueType': 'http://identifiers.org/doid/'},
#       {'path': 'hits.mondo.xrefs.omim',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/'}],
#      'x-JSONLDContext': 'mydisease.info/jsonld_context/mydisease_gene2disease.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/mydisease.info/jsonld_context/mydisease_gene2disease.json',
# ...
#   'output': ['http://biothings.io/explorer/vocab/terms/drug-name/',
#    'http://identifiers.org/chembl.compound/',
#    'http://biothings.io/explorer/vocab/terms/pharos.target/',
#    'http://identifiers.org/hgnc.symbol/',
#    'http://biothings.io/explorer/vocab/terms/pharos.disease/',
#    'http://biothings.io/explorer/vocab/terms/disease-name/'],
#   'relation': defaultdict(set,
#               {'http://biothings.io/explorer/vocab/terms/drug-name/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/chembl.compound/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/pharos.disease/': {'assoc:ChemicalToDiseaseOrPhenotypicFeatureAssociation'},
#                'http://biothings.io/explorer/vocab/terms/pharos.target/': {'assoc:ChemicalToGeneOrGeneProductAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/ChemicalToGeneOrGeneProductAssociation',
#    'http://biothings.io/explorer/vocab/objects/ChemicalToDiseaseOrPhenotypicFeatureAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/pharos.ligand/'],
#   'api': 'Pharos API',
#   'server': 'https://pharos.nih.gov/idg/api/v1'},
#  'https://pharos.nih.gov/idg/api/v1/diseases({diseaseid})': {'get': {'summary': 'get pharos disease information by pharos disease id',
#    'parameters': [{'name': 'diseaseid',
#      'in': 'path',
#      'description': 'Pharos disease id',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/pharos.disease/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.disease/',
#        'template': '/diseases({diseaseid})?view=full&format=jsonld'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A pharos ligand object',
#      'x-responseValueType': [{'path': 'name',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/disease-name/'},
#       {'path': 'synonyms.DOID', 'valueType': 'http://identifiers.org/doid/'},
#       {'path': 'synonyms.DiseaseOntology.term',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/omim.disease/'},
#       {'path': 'synonyms.DiseaseOntology.term',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/umls.disease/'},
#       {'path': 'links.ix.idg.models.Target.refid',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.target/'},
#       {'path': 'links.ix.idg.models.Target.properties.IDG Target.term',
#        'valueType': 'http://identifiers.org/hgnc.symbol/'},
#       {'path': 'links.ix.idg.models.Ligand.refid',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.ligand/'},
#       {'path': 'links.ix.idg.models.Ligand.properties.IDG Ligand/term',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/drug-name/'}],
#      'x-JSONLDContext': 'pharos/jsonld_context/pharos_disease.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/pharos/jsonld_context/pharos_disease.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/disease-name/',
#    'http://identifiers.org/doid/',
#    'http://biothings.io/explorer/vocab/terms/omim.disease/',
#    'http://biothings.io/explorer/vocab/terms/umls.disease/',
#    'http://biothings.io/explorer/vocab/terms/pharos.target/',
#    'http://identifiers.org/hgnc.symbol/',
#    'http://biothings.io/explorer/vocab/terms/pharos.ligand/',
#    'http://biothings.io/explorer/vocab/terms/drug-name/'],
#   'relation': defaultdict(set,
#               {'http://biothings.io/explorer/vocab/terms/disease-name/': {'assoc:EquivalentAssociation'},
#                'http://identifiers.org/doid/': {'assoc:EquivalentAssociation'},
#                'http://biothings.io/explorer/vocab/terms/pharos.target/': {'assoc:DiseaseToGeneOrGeneProductAssociation'},
#                'http://biothings.io/explorer/vocab/terms/pharos.disease/': {'assoc:DiseaseToChemicalAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation',
#    'http://biothings.io/explorer/vocab/objects/DiseaseToChemicalAssociation',
#    'http://biothings.io/explorer/vocab/objects/DiseaseToGeneOrGeneProductAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/pharos.disease/'],
#   'api': 'Pharos API',
#   'server': 'https://pharos.nih.gov/idg/api/v1'},
#  'https://pharos.nih.gov/idg/api/v1/ligands/search': {'get': {'summary': 'return pharos ligand id based on drugname',
#    'parameters': [{'name': 'q',
#      'in': 'query',
#      'description': 'Put drugname here, e.g. riluzole ',
#      'required': True,
#      'example': 'riluzole',
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/drug-name/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/drug-name/',
#        'template': 'input_value'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A pharos ligand annotation object',
#      'x-responseValueType': [{'path': 'content.id',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.ligand/'}],
#      'x-JSONLDContext': 'pharos/jsonld_context/pharos_drugname2ligand.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/pharos/jsonld_context/pharos_drugname2ligand.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/pharos.ligand/'],
#   'relation': defaultdict(set,
#               {'http://biothings.io/explorer/vocab/terms/pharos.ligand/': {'assoc:EquivalentAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/drug-name/'],
#   'api': 'Pharos API',
#   'server': 'https://pharos.nih.gov/idg/api/v1'},
#  'https://pharos.nih.gov/idg/api/v1/targets/search': {'get': {'summary': 'return pharos target id based on uniprot',
#    'parameters': [{'name': 'q',
#      'in': 'query',
#      'description': 'Put uniprot id here, e.g. P61073',
#      'required': True,
#      'example': 'P61073',
#      'x-valueType': ['http://identifiers.org/uniprot/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/uniprot/',
#        'template': 'input_value'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A pharos target annotation object',
#      'x-responseValueType': [{'path': 'content.id',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.target/'}],
#      'x-JSONLDContext': 'pharos/jsonld_context/pharos_uniprot2target.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/pharos/jsonld_context/pharos_uniprot2target.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/pharos.target/'],
#   'relation': defaultdict(set,
#               {'http://biothings.io/explorer/vocab/terms/pharos.target/': {'assoc:EquivalentAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation'],
#   'input': ['http://identifiers.org/uniprot/'],
#   'api': 'Pharos API',
#   'server': 'https://pharos.nih.gov/idg/api/v1'},
#  'https://pharos.nih.gov/idg/api/v1/diseases/search': {'get': {'summary': 'return pharos disease id based on disease name',
#    'parameters': [{'name': 'q',
#      'in': 'query',
#      'description': 'Put disease name here, e.g. cancer',
#      'required': True,
#      'example': 'cancer',
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/disease-name/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/disease-name/',
#        'template': 'input_value'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A pharos disease annotation object',
#      'x-responseValueType': [{'path': 'content.id',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/pharos.disease/'}],
#      'x-JSONLDContext': 'pharos/jsonld_context/pharos_diseasename2disease.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/pharos/jsonld_context/pharos_diseasename2disease.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/pharos.disease/'],
#   'relation': defaultdict(set,
#               {'http://biothings.io/explorer/vocab/terms/pharos.disease/': {'assoc:EquivalentAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/EquivalentAssociation'],
#   'input': ['http://biothings.io/explorer/vocab/terms/disease-name/'],
#   'api': 'Pharos API',
#   'server': 'https://pharos.nih.gov/idg/api/v1'},
#  'https://www.ncbi.nlm.nih.gov/research/bionlp/litvar/api/v1/public/rsids2pmids': {'get': {'summary': 'Retrieve PMIDs of publications mentioning submitted variants',
#    'parameters': [{'name': 'rsids',
#      'in': 'query',
#      'description': 'rsid',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/dbsnp/'],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'publications mentioned the submitted variant',
#      'x-responseValueType': [{'path': 'data.pmids',
#        'valueType': 'http://identifiers.org/pubmed/'}],
#      'x-JSONLDContext': 'litvar/jsonld_context/rsid2pmid_context.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/litvar/jsonld_context/rsid2pmid_context.json',
#   'output': ['http://identifiers.org/pubmed/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/pubmed/': {'assoc:VariantToPublicationAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/VariantToPublicationAssociation'],
#   'input': ['http://identifiers.org/dbsnp/'],
#   'api': 'LitVar API',
#   'server': 'https://www.ncbi.nlm.nih.gov/research/bionlp/litvar/api/v1'},
#  'http://rest.ensembl.org/variation/human/pmid/{pmid}': {'get': {'summary': 'Fetch variants by publication using PubMed reference number (PMID)',
#    'parameters': [{'name': 'pmid',
#      'in': 'path',
#      'description': 'PubMed reference number (PMID)',
#      'required': True,
#      'example': 26318936,
#      'x-valueType': ['http://identifiers.org/pubmed/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/pubmed/',
#        'template': '/variation/human/pmid/{pmid}?content-type=application/json'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A variant annotation object',
#      'x-responseValueType': [{'path': 'name',
#        'valueType': 'http://identifiers.org/dbsnp/'}],
#      'x-JSONLDContext': 'ensembl/jsonld_context/pmid2rsid_context.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/ensembl/jsonld_context/pmid2rsid_context.json',
#   'output': ['http://identifiers.org/dbsnp/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/dbsnp/': {'assoc:PublicationToVariantAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/PublicationToVariantAssociation'],
#   'input': ['http://identifiers.org/pubmed/'],
#   'api': 'Ensembl API',
#   'server': 'http://rest.ensembl.org'},
#  'http://rest.ensembl.org/variation/human/{rsid}': {'get': {'summary': 'Uses a variant identifier (e.g. rsID) to return phenotypic feature associated with the variant',
#    'parameters': [{'name': 'rsid',
#      'in': 'path',
#      'description': 'Variant id',
#      'required': True,
#      'example': 'rs56116432',
#      'x-valueType': ['http://identifiers.org/dbsnp/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/dbsnp/',
#        'template': '/variation/human/{rsid}?phenotypes=1;content-type=application/json'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'A phenoytpe annotation object',
#      'x-responseValueType': [{'path': 'phenotypes.trait',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/phenotype-name/'},
#       {'path': 'phenotypes.ontology_accessions',
#        'valueType': 'http://identifiers.org/hp/'}],
#      'x-JSONLDContext': 'ensembl/jsonld_context/rsid2phenotype_context.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/ensembl/jsonld_context/rsid2phenotype_context.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/phenotype-name/',
#    'http://identifiers.org/hp/'],
#   'relation': defaultdict(set,
#               {'http://identifiers.org/hp/': {'assoc:VariantToDiseaseOrPhenotypicFeatureAssociation'}}),
#   'associations': ['http://biothings.io/explorer/vocab/objects/VariantToDiseaseOrPhenotypicFeatureAssociation'],
#   'input': ['http://identifiers.org/dbsnp/'],
#   'api': 'Ensembl API',
#   'server': 'http://rest.ensembl.org'},
#  'http://rest.ensembl.org/taxonomy/id/{taxonomyid}': {'get': {'summary': 'Search for a taxonomic term by its identifier or name',
#    'parameters': [{'name': 'taxonomyid',
#      'in': 'path',
#      'description': 'Put taxonomy ids here, e.g. 9606',
#      'required': True,
#      'x-valueType': ['http://identifiers.org/taxonomy/'],
#      'x-requestTemplate': [{'valueType': 'http://identifiers.org/taxonomy/',
#        'template': '/taxonomy/id/{taxonomyid}?content-type=application/json'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'taxonomy annotation information',
#      'x-responseValueType': [{'path': 'parent.id',
#        'valueType': 'http://identifiers.org/taxonomy/'}],
#      'x-JSONLDContext': 'ensembl/jsonld_context/ensembl_taxonomy_context.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/ensembl/jsonld_context/ensembl_taxonomy_context.json',
#   'output': ['http://identifiers.org/taxonomy/'],
#   'relation': defaultdict(set, {}),
#   'associations': [],
#   'input': ['http://identifiers.org/taxonomy/'],
#   'api': 'Ensembl API',
#   'server': 'http://rest.ensembl.org'},
#  'http://rest.ensembl.org/lookup/id/{geneid}': {'get': {'summary': 'Find the species and database for a single identifier e.g. gene, transcript, protein',
#    'parameters': [{'name': 'geneid',
#      'in': 'path',
#      'description': 'Put ensembl gene ids here, e.g. ENSG00000157764',
#      'required': True,
#      'x-valueType': ['http://biothings.io/explorer/vocab/terms/ensembl.gene/'],
#      'x-requestTemplate': [{'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.gene/',
#        'template': '/lookup/id/{geneid}?content-type=application/json;phenotypes=1;expand=1'}],
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'ensembl gene lookup information',
#      'x-responseValueType': [{'path': 'Transcript.Exon.id',
#        'valueType': 'http://identifiers.org/ensembl.exon/'},
#       {'path': 'Transcript.Translation.id',
#        'valueType': 'http://biothings.io/explorer/vocab/terms/ensembl.protein/'},
#       {'path': 'phenotypes.ontology_accessions',
#        'valueType': 'http://identifiers.org/efo/'},
#       {'path': 'phenotypes.ontology_accessions',
#        'valueType': 'http://identifiers.org/hp/'}],
#      'x-JSONLDContext': 'ensembl/jsonld_context/ensembl_gene_context.json'}}},
#   'jsonld_context': '/Users/kevinxin/Documents/work/biothings_explorer/biothings_explorer_web/src/biothings_explorer/openapi_specs/ensembl/jsonld_context/ensembl_gene_context.json',
#   'output': ['http://biothings.io/explorer/vocab/terms/ensembl.protein/',
#    'http://identifiers.org/efo/',
#    'http://identifiers.org/hp/'],
#   'relation': defaultdict(set, {}),
#   'associations': [],
#   'input': ['http://biothings.io/explorer/vocab/terms/ensembl.gene/'],
#   'api': 'Ensembl API',
#   'server': 'http://rest.ensembl.org'}}

# %%
registry.bioentity_info
# Out:
# {'http://identifiers.org/uberon/': {'description': 'Uberon is an integrated cross-species anatomy ontology representing a variety of entities classified according to traditional anatomical criteria such as structure, function and developmental lineage. The ontology includes comprehensive relationships to taxon-specific anatomical ontologies, allowing integration of functional, phenotype and expression data.',
#   'preferred_name': 'UBERON',
#   'semantic type': 'anatomy',
#   'pattern': '^UBERON\\:\\d+$',
#   'prefix': 'uberon',
#   'example': 'UBERON:0008203',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/mesh.anatomy/': {'description': "MeSH (Medical Subject Headings) is the National Library of Medicine's controlled vocabulary thesaurus. It consists of sets of terms naming descriptors in a hierarchical structure that permits searching at various levels of specificity. This thesaurus is used by NLM for indexing articles from biomedical journals, cataloguing of books, docume",
#   'preferred_name': 'mesh.anatomy',
#   'semantic type': 'anatomy',
#   'pattern': None,
#   'prefix': 'mesh.anatomy',
#   'example': '9738',
#   'attribute type': 'ID'},
#  'http://identifiers.org/cl/': {'description': 'The Cell Ontology is designed as a structured controlled vocabulary for cell types. The ontology was constructed for use by the model organism and other bioinformatics databases, incorporating cell types from prokaryotes to mammals, and includes plants and fungi.',
#   'preferred_name': 'Cell Type Ontology',
#   'semantic type': 'anatomy',
#   'pattern': '^CL:\\d{7}$',
#   'prefix': 'cl',
#   'example': 'CL:0000232',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/anatomy-description/': {'description': 'description of anatomy',
#   'preferred_name': 'Anatomy-description',
#   'semantic type': 'anatomy',
#   'pattern': None,
#   'prefix': 'anatomy-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/anatomy/': {'description': 'anatomy name',
#   'preferred_name': 'anatomy',
#   'semantic type': 'anatomy',
#   'pattern': None,
#   'prefix': 'anatomy',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://identifiers.org/pubchem.bioassay/': {'description': "PubChem provides information on the biological activities of small molecules. It is a component of NIH's Molecular Libraries Roadmap Initiative. PubChem bioassay archives active compounds and bioassay results.",
#   'preferred_name': 'PubChem-bioassay',
#   'semantic type': 'bioassay',
#   'pattern': '^\\d+$',
#   'prefix': 'pubchem.bioassay',
#   'example': '1018',
#   'attribute type': 'ID'},
#  'http://identifiers.org/chembl.compound/': {'description': 'ChEMBL is a database of bioactive compounds, their quantitative properties and bioactivities (binding constants, pharmacology and ADMET, etc). The data is abstracted and curated from the primary scientific literature.',
#   'preferred_name': 'ChEMBL compound',
#   'semantic type': 'chemical',
#   'pattern': '^CHEMBL\\d+$',
#   'prefix': 'chembl.compound',
#   'example': 'CHEMBL744',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/drug-name/': {'description': 'name of a drug',
#   'preferred_name': 'drug-name',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'drug-name',
#   'example': 'riluzole',
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/chemical-description/': {'description': 'description of a drug',
#   'preferred_name': 'chemical-description',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'chemical-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://identifiers.org/inchikey/': {'description': 'The IUPAC International Chemical Identifier (InChI, see MIR:00000383) is an identifier for chemical substances, and is derived solely from a structural representation of that substance. Since these can be quite unwieldly, particularly for web use, the InChIKey was developed. These are of a fixed length (25 character) and were created as a condensed, more web friendly, digital representation of the InChI.',
#   'preferred_name': 'InChIKey',
#   'semantic type': 'chemical',
#   'pattern': '^[A-Z]{14}\\-[A-Z]{10}(\\-[A-Z])?',
#   'prefix': 'inchikey',
#   'example': 'RYYVLZVUVIJVGH-UHFFFAOYSA-N',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/pharos.ligand/': {'description': 'pharos ligand id',
#   'preferred_name': 'pharos.ligand',
#   'semantic type': 'chemical',
#   'pattern': '^\\d+$',
#   'prefix': 'pharos.ligand',
#   'example': '1',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/rxcui/': {'description': 'The RxNorm concept unique identifer for the clinical drug or substance involved in the event',
#   'preferred_name': 'rxcui',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'rxcui',
#   'example': '35623',
#   'attribute type': 'ID'},
#  'http://identifiers.org/chebi/': {'description': "Chemical Entities of Biological Interest (ChEBI) is a freely available dictionary of molecular entities focused on 'small' chemical compounds.",
#   'preferred_name': 'ChEBI',
#   'semantic type': 'chemical',
#   'pattern': '^CHEBI:\\d+$',
#   'prefix': 'chebi',
#   'example': 'CHEBI:36927',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/umls.compound/': {'description': 'The Unified Medical Language System is a repository of biomedical vocabularies. Vocabularies integrated in the UMLS Metathesaurus include the NCBI taxonomy, Gene Ontology, the Medical Subject Headings (MeSH), OMIM and the Digital Anatomist Symbolic Knowledge Base. UMLS concepts are not only inter-related, but may also be linked to external resources such as GenBank.',
#   'preferred_name': 'umls.compound',
#   'semantic type': 'chemical',
#   'pattern': '^C\\d+$',
#   'prefix': 'umls.compound',
#   'example': 'C0073379',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/mesh.compound/': {'description': 'mesh compound id',
#   'preferred_name': 'mesh.compound',
#   'semantic type': 'chemical',
#   'pattern': '^(C|D)\\d{6}$',
#   'prefix': 'mesh.compound',
#   'example': 'D019782',
#   'attribute type': 'ID'},
#  'http://identifiers.org/drugbank/': {'description': 'The DrugBank database is a bioinformatics and chemoinformatics resource that combines detailed drug (i.e. chemical, pharmacological and pharmaceutical) data with comprehensive drug target (i.e. sequence, structure, and pathway) information. This collection references drug information.',
#   'preferred_name': 'DrugBank',
#   'semantic type': 'chemical',
#   'pattern': '^DB\\d{5}$',
#   'prefix': 'drugbank',
#   'example': 'DB00001',
#   'attribute type': 'ID'},
#  'http://identifiers.org/iuphar.ligand/': {'description': 'The IUPHAR Compendium details the molecular, biophysical and pharmacological properties of identified mammalian sodium, calcium and potassium channels, as well as the related cyclic nucleotide-modulated ion channels and the recently described transient receptor potential channels. It includes information on nomenclature systems, and on inter and intra-species molecular structure variation. This collection references ligands.',
#   'preferred_name': 'IUPHAR ligand',
#   'semantic type': 'chemical',
#   'pattern': '^\\d+$',
#   'prefix': 'iuphar.ligand',
#   'example': '1755',
#   'attribute type': 'ID'},
#  'http://identifiers.org/kegg.drug/': {'description': 'KEGG DRUG contains chemical structures of drugs and additional information such as therapeutic categories and target molecules.',
#   'preferred_name': 'KEGG Drug',
#   'semantic type': 'chemical',
#   'pattern': '^D\\d+$',
#   'prefix': 'kegg.drug',
#   'example': 'D00123',
#   'attribute type': 'ID'},
#  'http://identifiers.org/kegg.compound/': {'description': 'KEGG compound contains our knowledge on the universe of chemical substances that are relevant to life.',
#   'preferred_name': 'KEGG Compound',
#   'semantic type': 'chemical',
#   'pattern': '^C\\d+$',
#   'prefix': 'kegg.compound',
#   'example': 'C12345',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pubchem.compound/': {'description': "PubChem provides information on the biological activities of small molecules. It is a component of NIH's Molecular Libraries Roadmap Initiative. PubChem Compound archives chemical structures and records.",
#   'preferred_name': 'PubChem-compound',
#   'semantic type': 'chemical',
#   'pattern': '^\\d+$',
#   'prefix': 'pubchem.compound',
#   'example': '5070',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pubchem.substance/': {'description': "PubChem provides information on the biological activities of small molecules. It is a component of NIH's Molecular Libraries Roadmap Initiative. PubChem Substance archives chemical substance records.",
#   'preferred_name': 'PubChem-substance',
#   'semantic type': 'chemical',
#   'pattern': '^\\d+$',
#   'prefix': 'pubchem.substance',
#   'example': '223440865',
#   'attribute type': 'ID'},
#  'http://identifiers.org/unii/': {'description': 'The purpose of the joint FDA/USP Substance Registration System (SRS) is to support health information technology initiatives by generating unique ingredient identifiers (UNIIs) for substances in drugs, biologics, foods, and devices. The UNII is a non- proprietary, free, unique, unambiguous, non semantic, alphanumeric identifier based on a substance\x89Ûªs molecular structure and/or descriptive information.',
#   'preferred_name': 'UNII',
#   'semantic type': 'chemical',
#   'pattern': '^[A-Z0-9]+$',
#   'prefix': 'unii',
#   'example': '3G6A5W338E',
#   'attribute type': 'ID'},
#  'http://identifiers.org/inchi/': {'description': 'The IUPAC International Chemical Identifier (InChI) is a non-proprietary identifier for chemical substances that can be used in printed and electronic data sources. It is derived solely from a structural representation of that substance, such that a single compound always yields the same identifier.',
#   'preferred_name': 'InChI',
#   'semantic type': 'chemical',
#   'pattern': '^InChI\\=1S?\\/[A-Za-z0-9\\.]+(\\+[0-9]+)?(\\/[cnpqbtmsih][A-Za-z0-9\\-\\+\\(\\)\\,\\/\\?\\;\\.]+)*$',
#   'prefix': 'inchi',
#   'example': 'InChI=1S/C2H6O/c1-2-3/h3H,2H2,1H3',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pharmgkb.drug/': {'description': 'The PharmGKB database is a central repository for genetic, genomic, molecular and cellular phenotype data and clinical information about people who have participated in pharmacogenomics research studies. The data includes, but is not limited to, clinical and basic pharmacokinetic and pharmacogenomic research in the cardiovascular, pulmonary, cancer, pathways, metabolic and transporter domains.',
#   'preferred_name': 'PharmGKB Drug',
#   'semantic type': 'chemical',
#   'pattern': '^PA\\d+$',
#   'prefix': 'pharmgkb.drug',
#   'example': 'PA448710',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/ndfrt/': {'description': 'NDF-RT combines the NDF hierarchical drug classification with a multi-category reference model.',
#   'preferred_name': 'ndfrt',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'ndfrt',
#   'example': 'N0000006860',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/epc-description/': {'description': 'An FDA ÒEstablished Pharmacologic ClassÓ (EPC) text phrase is a pharmacologic class associated with an approved indication of an active moiety that the FDA has determined to be scientifically valid and clinically meaningful.',
#   'preferred_name': 'EPC-Description',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'epc-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/drug-phase/': {'description': 'drug phase',
#   'preferred_name': 'Drug-Phase',
#   'semantic type': 'chemical',
#   'pattern': None,
#   'prefix': 'drug-phase',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://identifiers.org/snomedct/': {'description': 'SNOMED CT (Systematized Nomenclature of Medicine -- Clinical Terms), is a systematically organized computer processable collection of medical terminology covering most areas of clinical information such as diseases, findings, procedures, microorganisms, pharmaceuticals, etc.',
#   'preferred_name': 'SNOMED CT',
#   'semantic type': 'disease',
#   'pattern': '^(\\w+)?\\d+$',
#   'prefix': 'snomedct',
#   'example': '284196006',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/disease-name/': {'description': 'disease name',
#   'preferred_name': 'disease-name',
#   'semantic type': 'disease',
#   'pattern': None,
#   'prefix': 'disease-name',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://identifiers.org/meddra/': {'description': 'The Medical Dictionary for Regulatory Activities (MedDRA) was developed by the International Council for Harmonisation of Technical Requirements for Registration of Pharmaceuticals for Human Use (ICH)to provide a standardised medical terminology to facilitate sharing of regulatory information internationally for medical products used by humans. It is used within regulatory processes, safety monitoring, as well as for marketing activities. Products covered by the scope of MedDRA include pharmaceuticals, biologics, vaccines and drug-device combination products. The MedDRA dictionary is organized by System Organ Class (SOC), divided into High-Level Group Terms (HLGT), High-Level Terms (HLT), Preferred Terms (PT) and finally into Lowest Level Terms (LLT).',
#   'preferred_name': 'MedDRA',
#   'semantic type': 'disease',
#   'pattern': '^\\d+$',
#   'prefix': 'meddra',
#   'example': '10015919',
#   'attribute type': 'ID'},
#  'http://identifiers.org/orphanet/': {'description': 'Orphanet is a reference portal for information on rare diseases and orphan drugs. It\x89Ûªs aim is to help improve the diagnosis, care and treatment of patients with rare diseases.',
#   'preferred_name': 'Orphanet',
#   'semantic type': 'disease',
#   'pattern': '^\\d+$',
#   'prefix': 'orphanet',
#   'example': '85163',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/disease-description/': {'description': 'disease description',
#   'preferred_name': 'disease-description',
#   'semantic type': 'disease',
#   'pattern': None,
#   'prefix': 'disease-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/mesh.disease/': {'description': "MeSH (Medical Subject Headings) is the National Library of Medicine's controlled vocabulary thesaurus. It consists of sets of terms naming descriptors in a hierarchical structure that permits searching at various levels of specificity. This thesaurus is used by NLM for indexing articles from biomedical journals, cataloguing of books, docume",
#   'preferred_name': 'mesh.disease',
#   'semantic type': 'disease',
#   'pattern': '^(C|D)\\d{6}$',
#   'prefix': 'mesh.disease',
#   'example': 'D007619',
#   'attribute type': 'ID'},
#  'http://identifiers.org/ncit/': {'description': 'NCI Thesaurus (NCIt) provides reference terminology covering vocabulary for clinical care, translational and basic research, and public information and administrative activities, providing a stable and unique identification code.',
#   'preferred_name': 'NCIt',
#   'semantic type': 'disease',
#   'pattern': '^C\\d+$',
#   'prefix': 'ncit',
#   'example': 'C80519',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/pharos.disease/': {'description': 'pharos disease id',
#   'preferred_name': 'pharos.disease',
#   'semantic type': 'disease',
#   'pattern': '^\\d+$',
#   'prefix': 'pharos.disease',
#   'example': '1',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/umls.disease/': {'description': 'The Unified Medical Language System is a repository of biomedical vocabularies. Vocabularies integrated in the UMLS Metathesaurus include the NCBI taxonomy, Gene Ontology, the Medical Subject Headings (MeSH), OMIM and the Digital Anatomist Symbolic Knowledge Base. UMLS concepts are not only inter-related, but may also be linked to external resources such as GenBank.',
#   'preferred_name': 'umls.disease',
#   'semantic type': 'disease',
#   'pattern': '^C\\d+$',
#   'prefix': 'umls.disease',
#   'example': 'C0022521',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/omim.disease/': {'description': 'omim disease id',
#   'preferred_name': 'omim.disease',
#   'semantic type': 'disease',
#   'pattern': '^[*#+%^]?\\d{6}$',
#   'prefix': 'omim.disease',
#   'example': '244400',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/mondo/': {'description': 'mondo disease id',
#   'preferred_name': 'MONDO',
#   'semantic type': 'disease',
#   'pattern': '^MONDO\\:\\d+$',
#   'prefix': 'mondo',
#   'example': 'MONDO:0016575',
#   'attribute type': 'ID'},
#  'http://identifiers.org/doid/': {'description': 'The Disease Ontology has been developed as a standardized ontology for human disease with the purpose of providing the biomedical community with consistent, reusable and sustainable descriptions of human disease terms, phenotype characteristics and related medical vocabulary disease concepts.',
#   'preferred_name': 'Human Disease Ontology',
#   'semantic type': 'disease',
#   'pattern': '^DOID\\:\\d+$',
#   'prefix': 'doid',
#   'example': 'DOID:11337',
#   'attribute type': 'ID'},
#  'http://identifiers.org/hgnc/': {'description': 'The HGNC (HUGO Gene Nomenclature Committee) provides an approved gene name and symbol (short-form abbreviation) for each known human gene.  All approved symbols are stored in the HGNC database, and each symbol is unique. HGNC identifiers refer to records in the HGNC symbol database.',
#   'preferred_name': 'HGNC',
#   'semantic type': 'gene',
#   'pattern': '^((HGNC|hgnc):)?\\d{1,5}$',
#   'prefix': 'hgnc',
#   'example': '2674',
#   'attribute type': 'ID'},
#  'http://identifiers.org/hgnc.symbol/': {'description': 'The HGNC (HUGO Gene Nomenclature Committee) provides an approved gene name and symbol (short-form abbreviation) for each known human gene. All approved symbols are stored in the HGNC database, and each symbol is unique. This collection refers to records using the HGNC symbol.',
#   'preferred_name': 'HGNC Symbol',
#   'semantic type': 'gene',
#   'pattern': '^[A-Za-z-0-9_]+(\\@)?$',
#   'prefix': 'hgnc.symbol',
#   'example': 'CDK7',
#   'attribute type': 'ID'},
#  'http://identifiers.org/ncbigene/': {'description': "Entrez Gene is the NCBI's database for gene-specific information, focusing on completely sequenced genomes, those with an active research community to contribute gene-specific information, or those that are scheduled for intense sequence analysis.",
#   'preferred_name': 'NCBI Gene',
#   'semantic type': 'gene',
#   'pattern': '^\\d+$',
#   'prefix': 'ncbigene',
#   'example': '1019',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/umls.gene/': {'description': 'umls gene id',
#   'preferred_name': 'umls.gene',
#   'semantic type': 'gene',
#   'pattern': '^C\\d+$',
#   'prefix': 'umls.gene',
#   'example': 'C1332733',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/gene-approved-name/': {'description': 'gene approved name',
#   'preferred_name': 'gene-approved-name',
#   'semantic type': 'gene',
#   'pattern': None,
#   'prefix': 'gene-approved-name',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/gene-description/': {'description': 'description for gene',
#   'preferred_name': 'gene-description',
#   'semantic type': 'gene',
#   'pattern': None,
#   'prefix': 'gene-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://identifiers.org/ccds/': {'description': 'The Consensus CDS (CCDS) project is a collaborative effort to identify a core set of human and mouse protein coding regions that are consistently annotated and of high quality. The CCDS set is calculated following coordinated whole genome annotation updates carried out by the NCBI, WTSI, and Ensembl. The long term goal is to support convergence towards a standard set of gene annotations.',
#   'preferred_name': 'Consensus CDS',
#   'semantic type': 'gene',
#   'pattern': '^CCDS\\d+\\.\\d+$',
#   'prefix': 'ccds',
#   'example': 'CCDS13573.1',
#   'attribute type': 'ID'},
#  'http://identifiers.org/ena.embl/': {'description': 'The European Nucleotide Archive (ENA) captures and presents information relating to experimental workflows that are based around nucleotide sequencing. ENA is made up of a number of distinct databases that includes EMBL-Bank, the Sequence Read Archive (SRA) and the Trace Archive each with their own data formats and standards. This collection references Embl-Bank identifiers.',
#   'preferred_name': 'ENA',
#   'semantic type': 'gene',
#   'pattern': '^[A-Z]+[0-9]+(\\.\\d+)?$',
#   'prefix': 'ena.embl',
#   'example': 'BN000065',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/ensembl.gene/': {'description': 'ensembl gene id',
#   'preferred_name': 'ensembl.gene',
#   'semantic type': 'gene',
#   'pattern': '^((ENS[FPTG]\\\\d{11}(\\\\.\\\\d+)?)|(FB\\\\w{2}\\\\d{7})|(Y[A-Z]{2}\\\\d{3}[a-zA-Z](\\\\-[A-Z])?)|([A-Z_a-z0-9]+(\\\\.)?(t)?(\\\\d+)?([a-z])?))$',
#   'prefix': 'ensembl.gene',
#   'example': 'ENSG00000123374',
#   'attribute type': 'ID'},
#  'http://identifiers.org/mirbase/': {'description': 'The miRBase Sequence Database is a searchable database of published miRNA sequences and annotation. The data were previously provided by the miRNA Registry. Each entry in the miRBase Sequence database represents a predicted hairpin portion of a miRNA transcript (termed mir in the database), with information on the location and sequence of the mature miRNA sequence (termed miR).',
#   'preferred_name': 'miRBase Sequence',
#   'semantic type': 'gene',
#   'pattern': 'MI\\d{7}',
#   'prefix': 'mirbase',
#   'example': 'MI0000001',
#   'attribute type': 'ID'},
#  'http://identifiers.org/mgi/': {'description': 'The Mouse Genome Database (MGD) project includes data on gene characterization, nomenclature, mapping, gene homologies among mammals, sequence links, phenotypes, allelic variants and mutants, and strain data.',
#   'preferred_name': 'Mouse Genome Database',
#   'semantic type': 'gene',
#   'pattern': '^MGI:\\d+$',
#   'prefix': 'mgi',
#   'example': 'MGI:2442292',
#   'attribute type': 'ID'},
#  'http://identifiers.org/wormbase/': {'description': 'The Mouse Genome Database (MGD) project includes data on gene characterization, nomenclature, mapping, gene homologies among mammals, sequence links, phenotypes, allelic variants and mutants, and strain data.',
#   'preferred_name': 'Worm Base',
#   'semantic type': 'gene',
#   'pattern': '^Worm:\\d+$',
#   'prefix': 'mgi',
#   'example': 'WBGene00013782',
#   'attribute type': 'ID'},
#  'http://identifiers.org/fb/': {'description': 'flybase id',
#   'preferred_name': 'flybase',
#   'semantic type': 'gene',
#   'pattern': '^FB\\w{2}\\d{7}$',
#   'prefix': 'flybase',
#   'example': 'FBgn0011293',
#   'attribute type': 'ID'},
#  'http://identifiers.org/xenbase/': {'description': 'Xenbase is the model organism database for Xenopus laevis and X. (Silurana) tropicalis. It contains genomic, development data and community information for Xenopus research. it includes gene expression patterns that incorporates image data from the literature, large scale screens and community submissions.',
#   'preferred_name': 'Xenbase',
#   'semantic type': 'gene',
#   'pattern': '^(XB-GENE-)?\\d+$',
#   'prefix': 'xenbase',
#   'example': '922462',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/omim.gene/': {'description': 'omim gene id',
#   'preferred_name': 'omim.gene',
#   'semantic type': 'gene',
#   'pattern': '^[*#+%^]?\\d{6}$',
#   'prefix': 'omim.gene',
#   'example': '116953',
#   'attribute type': 'ID'},
#  'http://identifiers.org/refseq/': {'description': 'The Reference Sequence (RefSeq) collection aims to provide a comprehensive, integrated, non-redundant set of sequences, including genomic DNA, transcript (RNA), and protein products.',
#   'preferred_name': 'RefSeq',
#   'semantic type': 'gene',
#   'pattern': '^((AC|AP|NC|NG|NM|NP|NR|NT|NW|XM|XP|XR|YP|ZP)_\\d+|(NZ\\_[A-Z]{4}\\d+))(\\.\\d+)?$',
#   'prefix': 'refseq',
#   'example': 'NP_012345',
#   'attribute type': 'ID'},
#  'http://identifiers.org/rgd/': {'description': 'Rat Genome Database seeks to collect, consolidate, and integrate rat genomic and genetic data with curated functional and physiological data and make these data widely available to the scientific community. This collection references genes.',
#   'preferred_name': 'Rat Genome Database',
#   'semantic type': 'gene',
#   'pattern': '^\\d{4,}$',
#   'prefix': 'rgd',
#   'example': '2018',
#   'attribute type': 'ID'},
#  'http://identifiers.org/sgd/': {'description': 'The Saccharomyces Genome Database (SGD) project collects information and maintains a database of the molecular biology of the yeast Saccharomyces cerevisiae.',
#   'preferred_name': 'SGD',
#   'semantic type': 'gene',
#   'pattern': '^((S\\d+$)|(Y[A-Z]{2}\\d{3}[a-zA-Z](\\-[A-Z])?))$',
#   'prefix': 'sgd',
#   'example': 'S000003909',
#   'attribute type': 'ID'},
#  'http://identifiers.org/zfin/': {'description': 'ZFIN serves as the zebrafish model organism database. This collection references all zebrafish biological entities in ZFIN.',
#   'preferred_name': 'ZFIN Bioentity',
#   'semantic type': 'gene',
#   'pattern': '^ZDB\\-\\w+\\-\\d+\\-\\d+$',
#   'prefix': 'zfin',
#   'example': 'ZDB-GENE-041118-11',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/pharos.target/': {'description': 'pharos target id',
#   'preferred_name': 'pharos.target',
#   'semantic type': 'gene',
#   'pattern': '^\\d+$',
#   'prefix': 'pharos.target',
#   'example': '1',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/reactome.complex/': {'description': 'reacomte complex id',
#   'preferred_name': 'reactome.complex',
#   'semantic type': 'gene',
#   'pattern': '(^R-[A-Z]{3}-\\d+(-\\d+)?(\\.\\d+)?$)|(^REACT_\\d+(\\.\\d+)?$)',
#   'prefix': 'reactome.complex',
#   'example': 'R-HSA-1497822',
#   'attribute type': 'ID'},
#  'http://identifiers.org/ro/': {'description': 'The OBO Relation Ontology provides consistent and unambiguous formal definitions of the relational expressions used in biomedical ontologies.',
#   'preferred_name': 'Relation Ontology',
#   'semantic type': 'ontology',
#   'pattern': '^RO:\\d+{7}$',
#   'prefix': 'ro',
#   'example': 'RO:0002533',
#   'attribute type': 'ID'},
#  'http://identifiers.org/go/': {'description': 'The Gene Ontology project provides a controlled vocabulary to describe gene and gene product attributes in any organism.',
#   'preferred_name': 'Gene Ontology',
#   'semantic type': 'ontology',
#   'pattern': '^GO:\\d{7}$',
#   'prefix': 'go',
#   'example': 'GO:0006915',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/go-term/': {'description': 'go term label',
#   'preferred_name': 'go-term',
#   'semantic type': 'ontology',
#   'pattern': None,
#   'prefix': 'go-term',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/go-description/': {'description': 'description for go term',
#   'preferred_name': 'godescription',
#   'semantic type': 'ontology',
#   'pattern': None,
#   'prefix': 'godescription',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/go-evidence/': {'description': 'go evidence code',
#   'preferred_name': 'go-evidence',
#   'semantic type': 'ontology',
#   'pattern': None,
#   'prefix': 'go-evidence',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://identifiers.org/taxonomy/': {'description': 'The taxonomy contains the relationships between all living forms for which nucleic acid or protein sequence have been determined.',
#   'preferred_name': 'Taxonomy',
#   'semantic type': 'organism',
#   'pattern': '^\\d+$',
#   'prefix': 'taxonomy',
#   'example': '9606',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/taxonomyname/': {'description': 'taxonomy label',
#   'preferred_name': 'taxonomyname',
#   'semantic type': 'taxonomy',
#   'pattern': None,
#   'prefix': 'taxonomyname',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/reactome.pathway/': {'description': 'reacomte pathway id',
#   'preferred_name': 'reactome.pathway',
#   'semantic type': 'pathway',
#   'pattern': '(^R-[A-Z]{3}-\\d+(-\\d+)?(\\.\\d+)?$)|(^REACT_\\d+(\\.\\d+)?$)',
#   'prefix': 'reactome.pathway',
#   'example': 'R-HSA-109582',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/reactome.displayname/': {'description': 'reacomte displayname id',
#   'preferred_name': 'reactome.displayname',
#   'semantic type': 'pathway',
#   'pattern': None,
#   'prefix': 'reactome.displayname',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/pathways-name/': {'description': 'description for pathway',
#   'preferred_name': 'pathwaysname',
#   'semantic type': 'pathway',
#   'pattern': None,
#   'prefix': 'pathwaysname',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://identifiers.org/biocarta.pathway/': {'description': 'BioCarta is a supplier and distributor of characterized reagents and assays for biopharmaceutical and academic research. It catalogs community produced online maps depicting molecular relationships from areas of active research, generating classical pathways as well as suggestions for new pathways. This collections references pathway maps.',
#   'preferred_name': 'BioCarta Pathway',
#   'semantic type': 'pathway',
#   'pattern': '^([hm]\\_)?\\w+Pathway$',
#   'prefix': 'biocarta.pathway',
#   'example': 'cellcyclepathway',
#   'attribute type': 'Name'},
#  'http://identifiers.org/kegg.pathway/': {'description': 'KEGG PATHWAY is a collection of manually drawn pathway maps representing our knowledge on the molecular interaction and reaction networks.',
#   'preferred_name': 'KEGG Pathway',
#   'semantic type': 'pathway',
#   'pattern': '^\\w{2,4}\\d{5}$',
#   'prefix': 'kegg.pathway',
#   'example': 'hsa00620',
#   'attribute type': 'ID'},
#  'http://identifiers.org/wikipathways/': {'description': 'WikiPathways is a resource providing an open and public collection of  pathway maps created and curated by the community in a Wiki like style.',
#   'preferred_name': 'WikiPathways',
#   'semantic type': 'pathway',
#   'pattern': 'WP\\d{1,5}(\\_r\\d+)?$',
#   'prefix': 'wikipathways',
#   'example': 'WP100',
#   'attribute type': 'ID'},
#  'http://identifiers.org/hp/': {'description': 'The Human Phenotype Ontology (HPO) aims to provide a standardized vocabulary of phenotypic abnormalities encountered in human disease. Each term in the HPO describes a phenotypic abnormality, such as atrial septal defect. The HPO is currently being developed using the medical literature, Orphanet, DECIPHER, and OMIM.',
#   'preferred_name': 'Human Phenotype Ontology',
#   'semantic type': 'phenotype',
#   'pattern': '^HP:\\d{7}$',
#   'prefix': 'hp',
#   'example': 'HP:0000118',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/phenotype-name/': {'description': 'name of phenotype',
#   'preferred_name': 'phenotype-name',
#   'semantic type': 'phenotype',
#   'pattern': None,
#   'prefix': 'phenotype-name',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/phenotype-evidence/': {'description': 'phenotype evidence',
#   'preferred_name': 'phenotype-evidence',
#   'semantic type': 'phenotype',
#   'pattern': None,
#   'prefix': 'phenotype-evidence',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/phenotype-description/': {'description': 'description of phenotype',
#   'preferred_name': 'phenotype-description',
#   'semantic type': 'phenotype',
#   'pattern': None,
#   'prefix': 'phenotype-description',
#   'example': None,
#   'attribute type': 'Description'},
#  'http://biothings.io/explorer/vocab/terms/ensembl.protein/': {'description': 'Ensembl is a joint project between EMBL - EBI and the Sanger Institute to develop a software system which produces and maintains automatic annotation on selected eukaryotic genomes. This collections also references outgroup organisms',
#   'preferred_name': 'ensembl.protein',
#   'semantic type': 'gene',
#   'pattern': '^((ENS[FPTG]\\\\d{11}(\\\\.\\\\d+)?)|(FB\\\\w{2}\\\\d{7})|(Y[A-Z]{2}\\\\d{3}[a-zA-Z](\\\\-[A-Z])?)|([A-Z_a-z0-9]+(\\\\.)?(t)?(\\\\d+)?([a-z])?))$',
#   'prefix': 'ensembl.protein',
#   'example': 'ENSP00000243067',
#   'attribute type': 'ID'},
#  'http://identifiers.org/uniprot/': {'description': 'The UniProt Knowledgebase (UniProtKB) is a comprehensive resource for protein sequence and functional information with extensive cross-references to more than 120 external databases. Besides amino acid sequence and a description, it also provides taxonomic data and citation information.',
#   'preferred_name': 'UniProt Knowledgebase',
#   'semantic type': 'gene',
#   'pattern': '^([A-N,R-Z][0-9]([A-Z][A-Z, 0-9][A-Z, 0-9][0-9]){1,2})|([O,P,Q][0-9][A-Z, 0-9][A-Z, 0-9][A-Z, 0-9][0-9])(\\.\\d+)?$',
#   'prefix': 'uniprot',
#   'example': 'P0DP23',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pdb/': {'description': 'The Protein Data Bank is the single worldwide archive of structural data of biological macromolecules.',
#   'preferred_name': 'Protein Data Bank',
#   'semantic type': 'gene',
#   'pattern': '^[0-9][A-Za-z0-9]{3}$',
#   'prefix': 'pdb',
#   'example': '2gc4',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pubmed/': {'description': 'PubMed is a service of the U.S. National Library of Medicine that includes citations from MEDLINE and other life science journals for biomedical articles back to the 1950s.',
#   'preferred_name': 'PubMed',
#   'semantic type': 'publication',
#   'pattern': '^\\d+$',
#   'prefix': 'pubmed',
#   'example': '16333295',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/genebank-common-name/': {'description': 'genebank common name',
#   'preferred_name': 'genebank-common-name',
#   'semantic type': 'taxonomy',
#   'pattern': None,
#   'prefix': 'genebank-common-name',
#   'example': None,
#   'attribute type': 'Name'},
#  'http://biothings.io/explorer/vocab/terms/ensembl.transcript/': {'description': 'Ensembl is a joint project between EMBL - EBI and the Sanger Institute to develop a software system which produces and maintains automatic annotation on selected eukaryotic genomes. This collections also references outgroup organisms',
#   'preferred_name': 'ensembl.transcript',
#   'semantic type': 'transcript',
#   'pattern': '^((ENS[FPTG]\\\\d{11}(\\\\.\\\\d+)?)|(FB\\\\w{2}\\\\d{7})|(Y[A-Z]{2}\\\\d{3}[a-zA-Z](\\\\-[A-Z])?)|([A-Z_a-z0-9]+(\\\\.)?(t)?(\\\\d+)?([a-z])?))$',
#   'prefix': 'ensembl.transcript',
#   'example': 'ENST00000266970',
#   'attribute type': 'ID'},
#  'http://biothings.io/explorer/vocab/terms/ensembl.translation/': {'description': 'Ensembl is a joint project between EMBL - EBI and the Sanger Institute to develop a software system which produces and maintains automatic annotation on selected eukaryotic genomes. This collections also references outgroup organisms',
#   'preferred_name': 'ensembl.translation',
#   'semantic type': 'transcript',
#   'pattern': '^((ENS[FPTG]\\\\d{11}(\\\\.\\\\d+)?)|(FB\\\\w{2}\\\\d{7})|(Y[A-Z]{2}\\\\d{3}[a-zA-Z](\\\\-[A-Z])?)|([A-Z_a-z0-9]+(\\\\.)?(t)?(\\\\d+)?([a-z])?))$',
#   'prefix': 'ensembl.translation',
#   'example': 'ENSP00000266970',
#   'attribute type': 'ID'},
#  'http://identifiers.org/unigene/': {'description': 'A UniGene entry is a set of transcript sequences that appear to come from the same transcription locus (gene or expressed pseudogene), together with information on protein similarities, gene expression, cDNA clone reagents, and genomic location.',
#   'preferred_name': 'UniGene',
#   'semantic type': 'transcript',
#   'pattern': '^\\d+$',
#   'prefix': 'unigene',
#   'example': '4900',
#   'attribute type': 'ID'},
#  'http://identifiers.org/dbsnp/': {'description': 'The dbSNP database is a repository for both single base nucleotide subsitutions and short deletion and insertion polymorphisms.',
#   'preferred_name': 'dbSNP',
#   'semantic type': 'variant',
#   'pattern': '^rs\\d+$',
#   'prefix': 'dbsnp',
#   'example': 'rs13078881',
#   'attribute type': 'ID'},
#  'http://identifiers.org/pharmgkb.pathways/': {'description': 'PharmGKB Pathways are drug centric, gene based, interactive pathways which focus on candidate genes and gene groups and associated genotype and phenotype data of relevance for pharmacogenetic and pharmacogenomic studies.',
#   'preferred_name': 'pharmgkb.pathway',
#   'semantic type': 'pathway',
#   'pattern': '^PA\\d+$',
#   'prefix': 'pharmgkb.pathway',
#   'example': 'PA165292177',
#   'attribute type': 'ID'},
#  'http://identifiers.org/clinicaltrials/': {'description': ' "ClinicalTrials.gov provides free access to information on clinical studies for a wide range of diseases and conditions. Studies listed in the database are conducted in 175 countries"',
#   'preferred_name': ' clinicaltrials',
#   'semantic type': ' clinicaltrail',
#   'pattern': ' ^NCT\\d{8}$',
#   'prefix': ' clinicaltrial',
#   'example': ' NCT00222573',
#   'attribute type': ' ID'},
#  'http://identifiers.org/efo/': {'description': 'The Experimental Factor Ontology (EFO) provides a systematic description of many experimental variables available in EBI databases. It combines parts of several biological ontologies, such as anatomy, disease and chemical compounds. The scope of EFO is to support the annotation, analysis and visualization of data handled by the EBI Functional Genomics Team.',
#   'preferred_name': 'efo',
#   'semantic type': 'phenotype',
#   'pattern': '^\\d{7}$',
#   'prefix': 'efo',
#   'example': '0004859',
#   'attribute type': 'ID'}}

# %%
from collections import defaultdict
nodes = []
api_list = []
edges = []
output_prefixes = defaultdict(list)
input_prefixes = defaultdict(list)
i = 1
node_dict = {}
for _api in registry.api_info.keys():
    api_dict[_api] = {'input_list': [], 'output_list': []}
for k, v in registry.endpoint_info.items():
    api_name = v['api']
    if api_name not in api_list:
        nodes.append({'group': 'api', 'id': i, 'label': api_name})
        api_list.append(api_name)
        api_id = i
        i += 1
    for _output in v['output']:
        _output_prefix = registry.bioentity_info[_output]['prefix']
        if _output_prefix not in node_dict:
            node_dict[_output_prefix] = i
            nodes.append({'group': api_name, 'id': i, 'label': _output_prefix})
            edges.append({'from': api_id, 'label': 'hasOutput', 'to': i})
            i += 1
        else:
            edges.append({'from': api_id, 'label': 'hasOutput', 'to': node_dict[_output_prefix]})
    for _input in v['input']:
        _input_prefix = registry.bioentity_info[_input]['prefix']
        if _input_prefix not in node_dict:
            node_dict[_input_prefix] = i
            nodes.append({'group': api_name, 'id': i, 'label': _input_prefix})
            edges.append({'from': i, 'label': 'hasInput', 'to': api_id})
            i += 1
        else:
            edges.append({'from': api_id, 'label': 'hasInput', 'to': node_dict[_input_prefix]})

# %%
nodes
# Out:
# [{'group': 'api', 'id': 1, 'label': 'MyGene.info API'},
#  {'group': 'MyGene.info API', 'id': 2, 'label': 'ncbigene'},
#  {'group': 'MyGene.info API', 'id': 3, 'label': 'hgnc.symbol'},
#  {'group': 'MyGene.info API', 'id': 4, 'label': 'refseq'},
#  {'group': 'MyGene.info API', 'id': 5, 'label': 'unigene'},
#  {'group': 'MyGene.info API', 'id': 6, 'label': 'uniprot'},
#  {'group': 'MyGene.info API', 'id': 7, 'label': 'pdb'},
#  {'group': 'MyGene.info API', 'id': 8, 'label': 'ensembl.protein'},
#  {'group': 'MyGene.info API', 'id': 9, 'label': 'ensembl.transcript'},
#  {'group': 'MyGene.info API', 'id': 10, 'label': 'biocarta.pathway'},
#  {'group': 'MyGene.info API', 'id': 11, 'label': 'kegg.pathway'},
#  {'group': 'MyGene.info API', 'id': 12, 'label': 'wikipathways'},
#  {'group': 'MyGene.info API', 'id': 13, 'label': 'pharmgkb.pathway'},
#  {'group': 'MyGene.info API', 'id': 14, 'label': 'reactome.pathway'},
#  {'group': 'MyGene.info API', 'id': 15, 'label': 'go'},
#  {'group': 'MyGene.info API', 'id': 16, 'label': 'umls.gene'},
#  {'group': 'MyGene.info API', 'id': 17, 'label': 'ensembl.gene'},
#  {'group': 'MyGene.info API', 'id': 18, 'label': 'omim.gene'},
#  {'group': 'MyGene.info API', 'id': 19, 'label': 'hgnc'},
#  {'group': 'MyGene.info API', 'id': 20, 'label': 'mirbase'},
#  {'group': 'api', 'id': 21, 'label': 'MyChem.info API'},
#  {'group': 'MyChem.info API', 'id': 22, 'label': 'inchikey'},
#  {'group': 'MyChem.info API', 'id': 23, 'label': 'snomedct'},
#  {'group': 'MyChem.info API', 'id': 24, 'label': 'drug-name'},
#  {'group': 'MyChem.info API', 'id': 25, 'label': 'drugbank'},
#  {'group': 'MyChem.info API', 'id': 26, 'label': 'chembl.compound'},
#  {'group': 'MyChem.info API', 'id': 27, 'label': 'pubchem.compound'},
#  {'group': 'MyChem.info API', 'id': 28, 'label': 'umls.compound'},
#  {'group': 'MyChem.info API', 'id': 29, 'label': 'mesh.compound'},
#  {'group': 'MyChem.info API', 'id': 30, 'label': 'chemical-description'},
#  {'group': 'MyChem.info API', 'id': 31, 'label': 'umls.disease'},
#  {'group': 'MyChem.info API', 'id': 32, 'label': 'disease-name'},
#  {'group': 'MyChem.info API', 'id': 33, 'label': 'meddra'},
#  {'group': 'MyChem.info API', 'id': 34, 'label': 'ndfrt'},
#  {'group': 'MyChem.info API', 'id': 35, 'label': 'drug-phase'},
#  {'group': 'MyChem.info API', 'id': 36, 'label': 'rxcui'},
#  {'group': 'MyChem.info API', 'id': 37, 'label': 'chebi'},
#  {'group': 'MyChem.info API', 'id': 38, 'label': 'iuphar.ligand'},
#  {'group': 'MyChem.info API', 'id': 39, 'label': 'kegg.drug'},
#  {'group': 'MyChem.info API', 'id': 40, 'label': 'kegg.compound'},
#  {'group': 'MyChem.info API', 'id': 41, 'label': 'unii'},
#  {'group': 'MyChem.info API', 'id': 42, 'label': 'inchi'},
#  {'group': 'MyChem.info API', 'id': 43, 'label': 'pharmgkb.drug'},
#  {'group': 'MyChem.info API', 'id': 44, 'label': 'dbsnp'},
#  {'group': 'MyChem.info API', 'id': 45, 'label': 'pubmed'},
#  {'group': 'MyChem.info API', 'id': 46, 'label': ' clinicaltrial'},
#  {'group': 'MyChem.info API', 'id': 47, 'label': 'pubchem.substance'},
#  {'group': 'api', 'id': 48, 'label': 'MyDisease.info API'},
#  {'group': 'MyDisease.info API', 'id': 49, 'label': 'disease-description'},
#  {'group': 'MyDisease.info API', 'id': 50, 'label': 'doid'},
#  {'group': 'MyDisease.info API', 'id': 51, 'label': 'omim.disease'},
#  {'group': 'MyDisease.info API', 'id': 52, 'label': 'mondo'},
#  {'group': 'MyDisease.info API', 'id': 53, 'label': 'hp'},
#  {'group': 'MyDisease.info API', 'id': 54, 'label': 'orphanet'},
#  {'group': 'api', 'id': 55, 'label': 'DGIdb API'},
#  {'group': 'api', 'id': 56, 'label': 'BioLink API'},
#  {'group': 'BioLink API', 'id': 57, 'label': 'phenotype-name'},
#  {'group': 'BioLink API', 'id': 58, 'label': 'uberon'},
#  {'group': 'BioLink API', 'id': 59, 'label': 'mgi'},
#  {'group': 'BioLink API', 'id': 60, 'label': 'zfin'},
#  {'group': 'BioLink API', 'id': 61, 'label': 'flybase'},
#  {'group': 'BioLink API', 'id': 62, 'label': 'xenbase'},
#  {'group': 'BioLink API', 'id': 63, 'label': 'rgd'},
#  {'group': 'BioLink API', 'id': 64, 'label': 'sgd'},
#  {'group': 'BioLink API', 'id': 65, 'label': 'cl'},
#  {'group': 'api', 'id': 66, 'label': 'ChEMBL API'},
#  {'group': 'ChEMBL API', 'id': 67, 'label': 'mesh.disease'},
#  {'group': 'ChEMBL API', 'id': 68, 'label': 'efo'},
#  {'group': 'api', 'id': 69, 'label': 'Disease Ontology API'},
#  {'group': 'Disease Ontology API', 'id': 70, 'label': 'ncit'},
#  {'group': 'api', 'id': 71, 'label': 'Reactome API'},
#  {'group': 'Reactome API', 'id': 72, 'label': 'reactome.complex'},
#  {'group': 'api', 'id': 73, 'label': 'Taxonomy API'},
#  {'group': 'Taxonomy API', 'id': 74, 'label': 'taxonomy'},
#  {'group': 'api', 'id': 75, 'label': 'PubChem API'},
#  {'group': 'PubChem API', 'id': 76, 'label': 'pubchem.bioassay'},
#  {'group': 'api', 'id': 77, 'label': 'EBI Ontology Service API'},
#  {'group': 'EBI Ontology Service API', 'id': 78, 'label': 'anatomy'},
#  {'group': 'EBI Ontology Service API',
#   'id': 79,
#   'label': 'anatomy-description'},
#  {'group': 'EBI Ontology Service API', 'id': 80, 'label': 'mesh.anatomy'},
#  {'group': 'EBI Ontology Service API',
#   'id': 81,
#   'label': 'phenotype-description'},
#  {'group': 'EBI Ontology Service API', 'id': 82, 'label': 'godescription'},
#  {'group': 'EBI Ontology Service API', 'id': 83, 'label': 'go-term'},
#  {'group': 'api', 'id': 84, 'label': 'Pharos API'},
#  {'group': 'Pharos API', 'id': 85, 'label': 'gene-approved-name'},
#  {'group': 'Pharos API', 'id': 86, 'label': 'pharos.disease'},
#  {'group': 'Pharos API', 'id': 87, 'label': 'pharos.ligand'},
#  {'group': 'Pharos API', 'id': 88, 'label': 'pharos.target'},
#  {'group': 'api', 'id': 89, 'label': 'LitVar API'},
#  {'group': 'api', 'id': 90, 'label': 'Ensembl API'}]

# %%
edges
# Out:
# [{'from': 1, 'label': 'hasOutput', 'to': 2},
#  {'from': 1, 'label': 'hasOutput', 'to': 3},
#  {'from': 1, 'label': 'hasInput', 'to': 3},
#  {'from': 4, 'label': 'hasInput', 'to': 1},
#  {'from': 1, 'label': 'hasOutput', 'to': 2},
#  {'from': 1, 'label': 'hasOutput', 'to': 3},
#  {'from': 5, 'label': 'hasInput', 'to': 1},
#  {'from': 6, 'label': 'hasInput', 'to': 1},
#  {'from': 7, 'label': 'hasInput', 'to': 1},
#  {'from': 8, 'label': 'hasInput', 'to': 1},
#  {'from': 9, 'label': 'hasInput', 'to': 1},
#  {'from': 1, 'label': 'hasOutput', 'to': 2},
#  {'from': 1, 'label': 'hasOutput', 'to': 3},
#  {'from': 10, 'label': 'hasInput', 'to': 1},
#  {'from': 11, 'label': 'hasInput', 'to': 1},
#  {'from': 12, 'label': 'hasInput', 'to': 1},
#  {'from': 13, 'label': 'hasInput', 'to': 1},
#  {'from': 14, 'label': 'hasInput', 'to': 1},
#  {'from': 1, 'label': 'hasOutput', 'to': 2},
#  {'from': 1, 'label': 'hasOutput', 'to': 3},
#  {'from': 15, 'label': 'hasInput', 'to': 1},
#  {'from': 1, 'label': 'hasOutput', 'to': 3},
#  {'from': 1, 'label': 'hasOutput', 'to': 16},
#  {'from': 1, 'label': 'hasOutput', 'to': 5},
#  {'from': 1, 'label': 'hasOutput', 'to': 6},
#  {'from': 1, 'label': 'hasOutput', 'to': 7},
#  {'from': 1, 'label': 'hasOutput', 'to': 10},
#  {'from': 1, 'label': 'hasOutput', 'to': 11},
#  {'from': 1, 'label': 'hasOutput', 'to': 14},
#  {'from': 1, 'label': 'hasOutput', 'to': 12},
#  {'from': 1, 'label': 'hasOutput', 'to': 13},
#  {'from': 1, 'label': 'hasOutput', 'to': 15},
#  {'from': 1, 'label': 'hasOutput', 'to': 17},
#  {'from': 1, 'label': 'hasOutput', 'to': 8},
#  {'from': 1, 'label': 'hasOutput', 'to': 9},
#  {'from': 1, 'label': 'hasOutput', 'to': 18},
#  {'from': 1, 'label': 'hasOutput', 'to': 19},
#  {'from': 1, 'label': 'hasOutput', 'to': 20},
#  {'from': 1, 'label': 'hasInput', 'to': 2},
#  {'from': 1, 'label': 'hasInput', 'to': 17},
#  {'from': 21, 'label': 'hasOutput', 'to': 22},
#  {'from': 21, 'label': 'hasInput', 'to': 6},
#  {'from': 21, 'label': 'hasOutput', 'to': 22},
#  {'from': 23, 'label': 'hasInput', 'to': 21},
#  {'from': 21, 'label': 'hasOutput', 'to': 22},
#  {'from': 21, 'label': 'hasOutput', 'to': 24},
#  {'from': 21, 'label': 'hasOutput', 'to': 25},
#  {'from': 21, 'label': 'hasOutput', 'to': 26},
#  {'from': 21, 'label': 'hasOutput', 'to': 27},
#  {'from': 21, 'label': 'hasOutput', 'to': 6},
#  {'from': 21, 'label': 'hasOutput', 'to': 28},
#  {'from': 21, 'label': 'hasOutput', 'to': 29},
#  {'from': 21, 'label': 'hasOutput', 'to': 30},
#  {'from': 21, 'label': 'hasOutput', 'to': 23},
#  {'from': 21, 'label': 'hasOutput', 'to': 31},
#  {'from': 21, 'label': 'hasOutput', 'to': 32},
#  {'from': 21, 'label': 'hasOutput', 'to': 33},
#  {'from': 21, 'label': 'hasOutput', 'to': 34},
#  {'from': 21, 'label': 'hasOutput', 'to': 35},
#  {'from': 36, 'label': 'hasInput', 'to': 21},
#  {'from': 37, 'label': 'hasInput', 'to': 21},
#  {'from': 21, 'label': 'hasInput', 'to': 26},
#  {'from': 21, 'label': 'hasInput', 'to': 25},
#  {'from': 38, 'label': 'hasInput', 'to': 21},
#  {'from': 39, 'label': 'hasInput', 'to': 21},
#  {'from': 40, 'label': 'hasInput', 'to': 21},
#  {'from': 21, 'label': 'hasInput', 'to': 27},
#  {'from': 41, 'label': 'hasInput', 'to': 21},
#  {'from': 42, 'label': 'hasInput', 'to': 21},
#  {'from': 21, 'label': 'hasInput', 'to': 24},
#  {'from': 43, 'label': 'hasInput', 'to': 21},
#  {'from': 21, 'label': 'hasOutput', 'to': 22},
#  {'from': 21, 'label': 'hasOutput', 'to': 24},
#  {'from': 21, 'label': 'hasOutput', 'to': 42},
#  {'from': 21, 'label': 'hasOutput', 'to': 41},
#  {'from': 21, 'label': 'hasOutput', 'to': 6},
#  {'from': 21, 'label': 'hasOutput', 'to': 25},
#  {'from': 21, 'label': 'hasOutput', 'to': 44},
#  {'from': 21, 'label': 'hasOutput', 'to': 45},
#  {'from': 21, 'label': 'hasOutput', 'to': 46},
#  {'from': 21, 'label': 'hasOutput', 'to': 36},
#  {'from': 21, 'label': 'hasOutput', 'to': 37},
#  {'from': 21, 'label': 'hasOutput', 'to': 26},
#  {'from': 21, 'label': 'hasOutput', 'to': 39},
#  {'from': 21, 'label': 'hasOutput', 'to': 40},
#  {'from': 21, 'label': 'hasOutput', 'to': 23},
#  {'from': 21, 'label': 'hasOutput', 'to': 31},
#  {'from': 21, 'label': 'hasOutput', 'to': 38},
#  {'from': 21, 'label': 'hasOutput', 'to': 32},
#  {'from': 21, 'label': 'hasOutput', 'to': 43},
#  {'from': 21, 'label': 'hasOutput', 'to': 27},
#  {'from': 21, 'label': 'hasOutput', 'to': 47},
#  {'from': 21, 'label': 'hasOutput', 'to': 28},
#  {'from': 21, 'label': 'hasOutput', 'to': 29},
#  {'from': 21, 'label': 'hasOutput', 'to': 30},
#  {'from': 21, 'label': 'hasInput', 'to': 22},
#  {'from': 21, 'label': 'hasInput', 'to': 25},
#  {'from': 48, 'label': 'hasOutput', 'to': 32},
#  {'from': 48, 'label': 'hasOutput', 'to': 49},
#  {'from': 48, 'label': 'hasOutput', 'to': 50},
#  {'from': 48, 'label': 'hasOutput', 'to': 51},
#  {'from': 48, 'label': 'hasOutput', 'to': 31},
#  {'from': 52, 'label': 'hasInput', 'to': 48},
#  {'from': 48, 'label': 'hasOutput', 'to': 2},
#  {'from': 48, 'label': 'hasOutput', 'to': 3},
#  {'from': 48, 'label': 'hasInput', 'to': 31},
#  {'from': 48, 'label': 'hasInput', 'to': 52},
#  {'from': 48, 'label': 'hasInput', 'to': 50},
#  {'from': 48, 'label': 'hasInput', 'to': 51},
#  {'from': 48, 'label': 'hasOutput', 'to': 44},
#  {'from': 48, 'label': 'hasInput', 'to': 31},
#  {'from': 48, 'label': 'hasInput', 'to': 52},
#  {'from': 48, 'label': 'hasInput', 'to': 50},
#  {'from': 48, 'label': 'hasInput', 'to': 51},
#  {'from': 48, 'label': 'hasOutput', 'to': 53},
#  {'from': 48, 'label': 'hasInput', 'to': 31},
#  {'from': 48, 'label': 'hasInput', 'to': 52},
#  {'from': 48, 'label': 'hasInput', 'to': 50},
#  {'from': 48, 'label': 'hasInput', 'to': 51},
#  {'from': 54, 'label': 'hasInput', 'to': 48},
#  {'from': 48, 'label': 'hasOutput', 'to': 50},
#  {'from': 48, 'label': 'hasOutput', 'to': 51},
#  {'from': 48, 'label': 'hasInput', 'to': 53},
#  {'from': 48, 'label': 'hasOutput', 'to': 50},
#  {'from': 48, 'label': 'hasOutput', 'to': 51},
#  {'from': 48, 'label': 'hasInput', 'to': 2},
#  {'from': 48, 'label': 'hasInput', 'to': 3},
#  {'from': 55, 'label': 'hasOutput', 'to': 3},
#  {'from': 55, 'label': 'hasInput', 'to': 24},
#  {'from': 55, 'label': 'hasInput', 'to': 26},
#  {'from': 55, 'label': 'hasOutput', 'to': 24},
#  {'from': 55, 'label': 'hasOutput', 'to': 26},
#  {'from': 55, 'label': 'hasInput', 'to': 3},
#  {'from': 56, 'label': 'hasOutput', 'to': 57},
#  {'from': 56, 'label': 'hasInput', 'to': 53},
#  {'from': 56, 'label': 'hasOutput', 'to': 32},
#  {'from': 56, 'label': 'hasInput', 'to': 52},
#  {'from': 56, 'label': 'hasInput', 'to': 51},
#  {'from': 56, 'label': 'hasInput', 'to': 50},
#  {'from': 56, 'label': 'hasOutput', 'to': 58},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasInput', 'to': 51},
#  {'from': 56, 'label': 'hasInput', 'to': 50},
#  {'from': 56, 'label': 'hasInput', 'to': 52},
#  {'from': 56, 'label': 'hasOutput', 'to': 53},
#  {'from': 56, 'label': 'hasInput', 'to': 51},
#  {'from': 56, 'label': 'hasInput', 'to': 50},
#  {'from': 56, 'label': 'hasInput', 'to': 54},
#  {'from': 56, 'label': 'hasInput', 'to': 52},
#  {'from': 56, 'label': 'hasOutput', 'to': 59},
#  {'from': 56, 'label': 'hasOutput', 'to': 60},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 61},
#  {'from': 56, 'label': 'hasOutput', 'to': 62},
#  {'from': 56, 'label': 'hasOutput', 'to': 63},
#  {'from': 56, 'label': 'hasOutput', 'to': 64},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 59},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasInput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 53},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasInput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 14},
#  {'from': 56, 'label': 'hasOutput', 'to': 11},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasInput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasOutput', 'to': 19},
#  {'from': 56, 'label': 'hasInput', 'to': 58},
#  {'from': 65, 'label': 'hasInput', 'to': 56},
#  {'from': 56, 'label': 'hasOutput', 'to': 58},
#  {'from': 56, 'label': 'hasInput', 'to': 53},
#  {'from': 56, 'label': 'hasOutput', 'to': 52},
#  {'from': 56, 'label': 'hasInput', 'to': 2},
#  {'from': 56, 'label': 'hasInput', 'to': 19},
#  {'from': 66, 'label': 'hasOutput', 'to': 26},
#  {'from': 66, 'label': 'hasInput', 'to': 24},
#  {'from': 66, 'label': 'hasOutput', 'to': 6},
#  {'from': 66, 'label': 'hasInput', 'to': 26},
#  {'from': 66, 'label': 'hasOutput', 'to': 26},
#  {'from': 66, 'label': 'hasOutput', 'to': 67},
#  {'from': 66, 'label': 'hasOutput', 'to': 53},
#  {'from': 66, 'label': 'hasOutput', 'to': 68},
#  {'from': 66, 'label': 'hasOutput', 'to': 54},
#  {'from': 66, 'label': 'hasInput', 'to': 26},
#  {'from': 69, 'label': 'hasOutput', 'to': 67},
#  {'from': 69, 'label': 'hasOutput', 'to': 70},
#  {'from': 69, 'label': 'hasOutput', 'to': 23},
#  {'from': 69, 'label': 'hasOutput', 'to': 51},
#  {'from': 69, 'label': 'hasOutput', 'to': 50},
#  {'from': 69, 'label': 'hasOutput', 'to': 32},
#  {'from': 69, 'label': 'hasInput', 'to': 50},
#  {'from': 71, 'label': 'hasOutput', 'to': 72},
#  {'from': 71, 'label': 'hasInput', 'to': 6},
#  {'from': 71, 'label': 'hasOutput', 'to': 14},
#  {'from': 71, 'label': 'hasInput', 'to': 72},
#  {'from': 71, 'label': 'hasOutput', 'to': 6},
#  {'from': 71, 'label': 'hasInput', 'to': 14},
#  {'from': 71, 'label': 'hasOutput', 'to': 6},
#  {'from': 71, 'label': 'hasInput', 'to': 6},
#  {'from': 73, 'label': 'hasOutput', 'to': 74},
#  {'from': 73, 'label': 'hasInput', 'to': 74},
#  {'from': 75, 'label': 'hasOutput', 'to': 76},
#  {'from': 75, 'label': 'hasInput', 'to': 3},
#  {'from': 75, 'label': 'hasOutput', 'to': 76},
#  {'from': 75, 'label': 'hasInput', 'to': 2},
#  {'from': 75, 'label': 'hasOutput', 'to': 47},
#  {'from': 75, 'label': 'hasInput', 'to': 76},
#  {'from': 75, 'label': 'hasOutput', 'to': 27},
#  {'from': 75, 'label': 'hasInput', 'to': 76},
#  {'from': 75, 'label': 'hasOutput', 'to': 47},
#  {'from': 75, 'label': 'hasInput', 'to': 27},
#  {'from': 75, 'label': 'hasOutput', 'to': 27},
#  {'from': 75, 'label': 'hasInput', 'to': 47},
#  {'from': 75, 'label': 'hasOutput', 'to': 45},
#  {'from': 75, 'label': 'hasInput', 'to': 27},
#  {'from': 75, 'label': 'hasOutput', 'to': 24},
#  {'from': 75, 'label': 'hasInput', 'to': 24},
#  {'from': 77, 'label': 'hasOutput', 'to': 78},
#  {'from': 77, 'label': 'hasOutput', 'to': 79},
#  {'from': 77, 'label': 'hasOutput', 'to': 80},
#  {'from': 77, 'label': 'hasInput', 'to': 58},
#  {'from': 77, 'label': 'hasOutput', 'to': 78},
#  {'from': 77, 'label': 'hasOutput', 'to': 79},
#  {'from': 77, 'label': 'hasInput', 'to': 65},
#  {'from': 77, 'label': 'hasOutput', 'to': 57},
#  {'from': 77, 'label': 'hasOutput', 'to': 81},
#  {'from': 77, 'label': 'hasInput', 'to': 53},
#  {'from': 77, 'label': 'hasOutput', 'to': 82},
#  {'from': 77, 'label': 'hasOutput', 'to': 83},
#  {'from': 77, 'label': 'hasInput', 'to': 15},
#  {'from': 77, 'label': 'hasOutput', 'to': 49},
#  {'from': 77, 'label': 'hasOutput', 'to': 32},
#  {'from': 77, 'label': 'hasInput', 'to': 50},
#  {'from': 77, 'label': 'hasOutput', 'to': 15},
#  {'from': 77, 'label': 'hasInput', 'to': 15},
#  {'from': 77, 'label': 'hasOutput', 'to': 15},
#  {'from': 77, 'label': 'hasInput', 'to': 15},
#  {'from': 77, 'label': 'hasOutput', 'to': 50},
#  {'from': 77, 'label': 'hasInput', 'to': 50},
#  {'from': 77, 'label': 'hasOutput', 'to': 50},
#  {'from': 77, 'label': 'hasInput', 'to': 50},
#  {'from': 77, 'label': 'hasOutput', 'to': 58},
#  {'from': 77, 'label': 'hasInput', 'to': 58},
#  {'from': 77, 'label': 'hasOutput', 'to': 58},
#  {'from': 77, 'label': 'hasInput', 'to': 58},
#  {'from': 84, 'label': 'hasOutput', 'to': 6},
#  {'from': 84, 'label': 'hasOutput', 'to': 3},
#  {'from': 84, 'label': 'hasOutput', 'to': 85},
#  {'from': 84, 'label': 'hasOutput', 'to': 2},
#  {'from': 84, 'label': 'hasOutput', 'to': 18},
#  {'from': 84, 'label': 'hasOutput', 'to': 86},
#  {'from': 84, 'label': 'hasOutput', 'to': 32},
#  {'from': 84, 'label': 'hasOutput', 'to': 87},
#  {'from': 84, 'label': 'hasOutput', 'to': 24},
#  {'from': 88, 'label': 'hasInput', 'to': 84},
#  {'from': 84, 'label': 'hasOutput', 'to': 24},
#  {'from': 84, 'label': 'hasOutput', 'to': 26},
#  {'from': 84, 'label': 'hasOutput', 'to': 88},
#  {'from': 84, 'label': 'hasOutput', 'to': 3},
#  {'from': 84, 'label': 'hasOutput', 'to': 86},
#  {'from': 84, 'label': 'hasOutput', 'to': 32},
#  {'from': 84, 'label': 'hasInput', 'to': 87},
#  {'from': 84, 'label': 'hasOutput', 'to': 32},
#  {'from': 84, 'label': 'hasOutput', 'to': 50},
#  {'from': 84, 'label': 'hasOutput', 'to': 51},
#  {'from': 84, 'label': 'hasOutput', 'to': 31},
#  {'from': 84, 'label': 'hasOutput', 'to': 88},
#  {'from': 84, 'label': 'hasOutput', 'to': 3},
#  {'from': 84, 'label': 'hasOutput', 'to': 87},
#  {'from': 84, 'label': 'hasOutput', 'to': 24},
#  {'from': 84, 'label': 'hasInput', 'to': 86},
#  {'from': 84, 'label': 'hasOutput', 'to': 87},
#  {'from': 84, 'label': 'hasInput', 'to': 24},
#  {'from': 84, 'label': 'hasOutput', 'to': 88},
#  {'from': 84, 'label': 'hasInput', 'to': 6},
#  {'from': 84, 'label': 'hasOutput', 'to': 86},
#  {'from': 84, 'label': 'hasInput', 'to': 32},
#  {'from': 89, 'label': 'hasOutput', 'to': 45},
#  {'from': 89, 'label': 'hasInput', 'to': 44},
#  {'from': 90, 'label': 'hasOutput', 'to': 44},
#  {'from': 90, 'label': 'hasInput', 'to': 45},
#  {'from': 90, 'label': 'hasOutput', 'to': 57},
#  {'from': 90, 'label': 'hasOutput', 'to': 53},
#  {'from': 90, 'label': 'hasInput', 'to': 44},
#  {'from': 90, 'label': 'hasOutput', 'to': 74},
#  {'from': 90, 'label': 'hasInput', 'to': 74},
#  {'from': 90, 'label': 'hasOutput', 'to': 8},
#  {'from': 90, 'label': 'hasOutput', 'to': 68},
#  {'from': 90, 'label': 'hasOutput', 'to': 53},
#  {'from': 90, 'label': 'hasInput', 'to': 17}]
