# %% [markdown]
# # 1. Making Data-structure Neutral Queries by URI

# %% [markdown]
# ##### Use Case Scenario1 : Query for the OMIM ID for a Variant Using myvariant.info

# %% [markdown]
# #### Approach 1: Using Myvariant.info

# %% [markdown]
# Users could retrieve the OMIM ID through myvariant.info; however, it requires the user to understand how OMIM ID is embedded in the data structure of MyVariant.info.

# %%
# import myvariant python package
import myvariant
mv = myvariant.MyVariantInfo()

# %%
# Fetch info about OMIM ID
mv.getvariant('chr9:g.135781006_135781007del', fields='clinvar.rcv.conditions.identifiers.omim')
# Out:
# {'_id': 'chr9:g.135781006_135781007del',
#  '_version': 1,
#  'clinvar': {'rcv': {'conditions': {'identifiers': {'omim': '109800'}}}}}

# %% [markdown]
# #### Approach 2: Using JSON-LD powered neutral query function

# %% [markdown]
# By utilizing JSON-LD in making queries, the process would be simplified significantly. Users only need to know the URI for OMIM ID, which is unique for any API. And it saves users significant amount of time in order to figure out the data structure for each API.

# %%
'''
import get_biothings function which is built utilizing JSON-LD technology
This function could be used to make neutral query for all BioThings APIs,
e.g MyGene.info, MyVariant.info, Drug and compound API
'''
from biothings_helper import get_biothings

# %%
# Fetch info about OMIM ID using URI for OMIM ID, which is 'http://identifiers.org/omim/'
get_biothings(api='myvariant.info',id='chr9:g.135781006_135781007del', fields_uri='http://identifiers.org/omim/')
# Out:
# {'_id': 'chr9:g.135781006_135781007del',
#  '_version': 1,
#  'clinvar': {'rcv': {'conditions': {'identifiers': {'omim': '109800'}}}}}

# %% [markdown]
# ##### Use Case Scenario2 : query for all variants in MyVariant.info related to gene CDK2

# %% [markdown]
# #### Approach 1: Using MyVariant.info

# %% [markdown]
# The traditional approach would first require the user to figure out which data source in MyVariant.info includes annotation information about gene names. Additionally, the user have to understand how gene name is represented and embedded in each of the data source.

# %%
# query for all variants in MyVariant.info related to gene CDK2 using myvariant python package
mv.query('clinvar.gene.symbol:CDK2 OR \
          docm.genename:CDK2 OR \
          snpeff.nmd.genename:CDK2 OR \
          gwassnps.genename:CDK2 OR \
          dbnsfp.genename:CDK2 OR \
          docm.default_gene_name:CDK2 OR \
          snpeff.ann.genename:CDK2 OR \
          snpeff.lof.genename:CDK2 OR \
          emv.gene.symbol:CDK2 OR \
          dbsnp.gene.symbol:CDK2 OR \
          evs.gene.symbol:CDK2 OR \
          cadd.gene.genename:CDK2', fetch_all=False)
# Out:
# {'hits': [{'_id': 'chr12:g.56361693G>T',
#    '_score': 8.73773,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'G',
#     'annotype': ['CodingTranscript', 'Intergenic', 'Intergenic'],
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.024,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.039,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.142,
#      'tssaflnk': 0.291,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.063,
#      'txwk': 0.181,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': ['stop_gained', 'upstream', 'upstream'],
#     'consequence': ['STOP_GAINED', 'UPSTREAM', 'UPSTREAM'],
#     'consscore': [8, 1, 1],
#     'cpg': 0.03,
#     'dna': {'helt': 0.43, 'mgw': 0.6, 'prot': -1.24, 'roll': 6.36},
#     'encode': {'exp': 521.18,
#      'h3k27ac': 20.96,
#      'h3k4me1': 29.52,
#      'h3k4me3': 55.04,
#      'nucleo': 2.1},
#     'exon': '2/7',
#     'fitcons': 0.623825,
#     'gc': 0.48,
#     'gene': [{'ccds_id': 'CCDS8898.1',
#       'cds': {'cdna_pos': 409,
#        'cds_pos': 169,
#        'rel_cdna_pos': 0.18,
#        'rel_cds_pos': 0.19},
#       'feature_id': 'ENST00000266970',
#       'gene_id': 'ENSG00000123374',
#       'genename': 'CDK2',
#       'prot': {'domain': 'ndomain', 'protpos': 57, 'rel_prot_pos': 0.19}},
#      {'ccds_id': 'CCDS55834.1',
#       'feature_id': 'ENST00000449260',
#       'gene_id': 'ENSG00000185664',
#       'genename': 'PMEL'},
#      {'feature_id': 'ENST00000554022',
#       'gene_id': 'ENSG00000258554',
#       'genename': 'RP11-973D8.4'}],
#     'gerp': {'n': 4.73, 'rs': 406.8, 'rs_pval': 1.65278e-39, 's': 4.73},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 403,
#     'min_dist_tss': 435,
#     'mutindex': -42,
#     'naa': '*',
#     'oaa': 'E',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.996, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.626, 'primate': 0.486, 'vertebrate': 5.559},
#     'pos': 56361693,
#     'rawscore': 11.874943,
#     'ref': 'G',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': 57,
#      'ref': 'E',
#      'refcodon': 'GAG'},
#     'alt': 'T',
#     'ancestral_allele': 'G',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.7981,
#      'score': 0.9969183004977041},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 22.49633,
#      'raw': 1.18564590828305},
#     'eigen-pc': {'phred': 20.46959,
#      'raw': 1.02513172599092,
#      'raw_rankscore': 0.9855},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970', 'ENSP00000452514', 'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000354056']},
#     'exac': {'ac': 1,
#      'adj_ac': 1,
#      'adj_af': 8.238e-06,
#      'af': 8.236e-06,
#      'afr_ac': 0,
#      'afr_af': 0,
#      'amr_ac': 0,
#      'amr_af': 0,
#      'eas_ac': 0,
#      'eas_af': 0,
#      'fin_ac': 0,
#      'fin_af': 0,
#      'nfe_ac': 1,
#      'nfe_af': 1.499e-05,
#      'sas_ac': 0,
#      'sas_af': 0},
#     'exac_nontcga': {'ac': 1,
#      'adj_ac': 1,
#      'adj_af': 9.417e-06,
#      'af': 9.415e-06,
#      'afr_ac': 0,
#      'afr_af': 0,
#      'amr_ac': 0,
#      'amr_af': 0,
#      'eas_ac': 0,
#      'eas_af': 0,
#      'fin_ac': 0,
#      'fin_af': 0,
#      'nfe_ac': 1,
#      'nfe_af': 1.84e-05,
#      'sas_ac': 0,
#      'sas_af': 0},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBCI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.70836,
#      'coding_score': 0.96805},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999999985},
#     'gerp++': {'nr': 4.73, 'rs': 4.73, 'rs_rankscore': 0.59331},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54647960, 'start': 54647960},
#     'hg19': {'end': 56361693, 'start': 56361693},
#     'hg38': {'end': 55967909, 'start': 55967909},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': 'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain',
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['E57*', 'E57*', 'E57*', '.'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'without_aae'],
#      'pred': ['A', 'A', 'A', 'D'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 9.985,
#       'vertebrate_rankscore': 0.99176},
#      'p20way': {'mammalian': 0.978, 'mammalian_rankscore': 0.59618}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'G',
#     'rsid': 'rs757201758',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 17.0098,
#      'logodds_rankscore': 0.86213,
#      'pi': {'a': 0.0, 'c': 0.0, 'g': 1.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'dbsnp': {'allele_origin': 'unspecified',
#     'alleles': [{'allele': 'G'}, {'allele': 'T'}],
#     'alt': 'T',
#     'chrom': '12',
#     'class': 'SNV',
#     'dbsnp_build': 144,
#     'flags': ['ASP', 'INT', 'NSN', 'R5', 'REF'],
#     'gene': [{'geneid': '1017', 'symbol': 'CDK2'},
#      {'geneid': '6490', 'symbol': 'PMEL'}],
#     'hg19': {'end': 56361693, 'start': 56361693},
#     'ref': 'G',
#     'rsid': 'rs757201758',
#     'validated': False,
#     'var_subtype': 'tv',
#     'vartype': 'snp'},
#    'exac': {'ac': {'ac': 1,
#      'ac_adj': 1,
#      'ac_afr': 0,
#      'ac_amr': 0,
#      'ac_eas': 0,
#      'ac_female': 1,
#      'ac_fin': 0,
#      'ac_het': 1,
#      'ac_hom': 0,
#      'ac_male': 0,
#      'ac_nfe': 1,
#      'ac_oth': 0,
#      'ac_sas': 0},
#     'af': 8.236e-06,
#     'alleles': 'T',
#     'alt': 'T',
#     'an': {'an': 121412,
#      'an_adj': 121396,
#      'an_afr': 10406,
#      'an_amr': 11572,
#      'an_eas': 8654,
#      'an_female': 54114,
#      'an_fin': 6614,
#      'an_male': 67282,
#      'an_nfe': 66732,
#      'an_oth': 906,
#      'an_sas': 16512},
#     'baseqranksum': -2.257,
#     'chrom': 12,
#     'clippingranksum': -0.394,
#     'culprit': 'MQRankSum',
#     'fs': 2.112,
#     'het': {'het_afr': 0,
#      'het_amr': 0,
#      'het_eas': 0,
#      'het_fin': 0,
#      'het_nfe': 1,
#      'het_oth': 0,
#      'het_sas': 0},
#     'hom': {'hom_afr': 0,
#      'hom_amr': 0,
#      'hom_eas': 0,
#      'hom_fin': 0,
#      'hom_nfe': 0,
#      'hom_oth': 0,
#      'hom_sas': 0},
#     'inbreedingcoeff': 0.0004,
#     'mq': {'mq': 59.71, 'mq0': 0, 'mqranksum': -0.856},
#     'ncc': 7,
#     'pos': 56361693,
#     'qd': 11.01,
#     'readposranksum': 0.802,
#     'ref': 'G',
#     'type': 'snp',
#     'vqslod': 0.69},
#    'exac_nontcga': {'ac': {'ac': 1,
#      'ac_adj': 1,
#      'ac_afr': 0,
#      'ac_amr': 0,
#      'ac_eas': 0,
#      'ac_female': 1,
#      'ac_fin': 0,
#      'ac_het': 1,
#      'ac_hom': 0,
#      'ac_male': 0,
#      'ac_nfe': 1,
#      'ac_oth': 0,
#      'ac_sas': 0},
#     'af': 9.415e-06,
#     'alleles': 'T',
#     'alt': 'T',
#     'an': {'an': 106210,
#      'an_adj': 106196,
#      'an_afr': 9066,
#      'an_amr': 11210,
#      'an_eas': 7866,
#      'an_female': 45866,
#      'an_fin': 6614,
#      'an_male': 60330,
#      'an_nfe': 54338,
#      'an_oth': 694,
#      'an_sas': 16408},
#     'baseqranksum': -2.257,
#     'chrom': 12,
#     'clippingranksum': -0.394,
#     'culprit': 'MQRankSum',
#     'fs': 2.112,
#     'het': {'het_afr': 0,
#      'het_amr': 0,
#      'het_eas': 0,
#      'het_fin': 0,
#      'het_nfe': 1,
#      'het_oth': 0,
#      'het_sas': 0},
#     'hom': {'hom_afr': 0,
#      'hom_amr': 0,
#      'hom_eas': 0,
#      'hom_fin': 0,
#      'hom_nfe': 0,
#      'hom_oth': 0,
#      'hom_sas': 0},
#     'inbreedingcoeff': 0.0004,
#     'mq': {'mq': 59.71, 'mq0': 0, 'mqranksum': -0.856},
#     'ncc': 7,
#     'pos': 56361693,
#     'qd': 11.01,
#     'readposranksum': 0.802,
#     'ref': 'G',
#     'type': 'snp',
#     'vqslod': 0.69},
#    'hg19': {'end': 56361693, 'start': 56361693},
#    'observed': True,
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '409'},
#       'cds': {'length': '897', 'position': '169'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.169G>T',
#       'hgvs_p': 'p.Glu57*',
#       'protein': {'length': '298', 'position': '57'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '409'},
#       'cds': {'length': '795', 'position': '169'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.169G>T',
#       'hgvs_p': 'p.Glu57*',
#       'protein': {'length': '264', 'position': '57'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1847',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1847',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1197',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'effect': 'intron_variant',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.117-140G>T',
#       'putative_impact': 'MODIFIER',
#       'rank': '1',
#       'total': '4',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '0.67'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '0.67'}},
#    'vcf': {'alt': 'T', 'position': '56361693', 'ref': 'G'}},
#   {'_id': 'chr12:g.56362574C>T',
#    '_score': 7.2263837,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'C',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 250,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.071,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.016,
#      'tssaflnk': 0.008,
#      'tssbiv': 0.0,
#      'tx': 0.15,
#      'txflnk': 0.039,
#      'txwk': 0.646,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.03,
#     'dna': {'helt': 1.21, 'mgw': 0.62, 'prot': -2.97, 'roll': 1.34},
#     'dst2splice': 13,
#     'dst2spltype': 'ACCEPTOR',
#     'encode': {'exp': 193.32,
#      'h3k27ac': 7.16,
#      'h3k4me1': 14.12,
#      'h3k4me3': 19.96,
#      'nucleo': 2.2},
#     'exon': '4/7',
#     'fitcons': 0.726386,
#     'gc': 0.5,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 568,
#       'cds_pos': 328,
#       'rel_cdna_pos': 0.25,
#       'rel_cds_pos': 0.37},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 110, 'rel_prot_pos': 0.37}},
#     'gerp': {'n': 4.53, 'rs': 602.1, 'rs_pval': 2.56976e-59, 's': 4.53},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'FALSE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 479,
#     'min_dist_tss': 1328,
#     'mutindex': -26,
#     'naa': '*',
#     'oaa': 'Q',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.985, 'vertebrate': 1.0},
#     'phred': 39,
#     'phylop': {'mammalian': 2.522, 'primate': 0.457, 'vertebrate': 5.459},
#     'pos': 56362574,
#     'rawscore': 12.632847,
#     'ref': 'C',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['110', '110', '84', '110'],
#      'ref': 'Q',
#      'refcodon': 'CAG'},
#     'alt': 'T',
#     'ancestral_allele': 'C',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.89712,
#      'score': 0.9981459634050125},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 17.64166,
#      'raw': 1.10312033626684},
#     'eigen-pc': {'phred': 15.25602,
#      'raw': 0.933325513156562,
#      'raw_rankscore': 0.96387},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.77402,
#      'coding_score': 0.97845},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.99999999999996},
#     'gerp++': {'nr': 4.53, 'rs': 4.53, 'rs_rankscore': 0.54846},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54648841, 'start': 54648841},
#     'hg19': {'end': 56362574, 'start': 56362574},
#     'hg38': {'end': 55968790, 'start': 55968790},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.9842,
#      'fitcons_score': 0.735409},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8535,
#      'fitcons_score': 0.722319},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Q110*', 'Q84*', 'Q110*', 'Q110*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 7.866,
#       'vertebrate_rankscore': 0.85362},
#      'p20way': {'mammalian': 0.886, 'mammalian_rankscore': 0.38909}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'C',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 16.5654,
#      'logodds_rankscore': 0.84367,
#      'pi': {'a': 0.0, 'c': 1.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56362574, 'start': 56362574},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '568'},
#       'cds': {'length': '897', 'position': '328'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.328C>T',
#       'hgvs_p': 'p.Gln110*',
#       'protein': {'length': '298', 'position': '110'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '490'},
#       'cds': {'length': '717', 'position': '250'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.250C>T',
#       'hgvs_p': 'p.Gln84*',
#       'protein': {'length': '238', 'position': '84'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '568'},
#       'cds': {'length': '795', 'position': '328'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.328C>T',
#       'hgvs_p': 'p.Gln110*',
#       'protein': {'length': '264', 'position': '110'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2728',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2728',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2078',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56362574', 'ref': 'C'}},
#   {'_id': 'chr12:g.56361903A>T',
#    '_score': 7.2185206,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': -3.16, 'mgw': 2.28, 'prot': 4.14, 'roll': 13.24},
#     'encode': {'exp': 696.29,
#      'h3k27ac': 10.16,
#      'h3k4me1': 19.92,
#      'h3k4me3': 29.88,
#      'nucleo': 1.1},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 505,
#       'cds_pos': 265,
#       'rel_cdna_pos': 0.22,
#       'rel_cds_pos': 0.3},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 89, 'rel_prot_pos': 0.3}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 5.26},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 193,
#     'min_dist_tss': 645,
#     'mutindex': -43,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.995, 'vertebrate': 1.0},
#     'phred': 40,
#     'phylop': {'mammalian': 2.122, 'primate': 0.398, 'vertebrate': 3.1},
#     'pos': 56361903,
#     'rawscore': 12.734282,
#     'ref': 'A',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['89', '89', '63', '89'],
#      'ref': 'K',
#      'refcodon': 'AAA'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.72936,
#      'score': 0.9958366694956521},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 9.623577,
#      'raw': 0.840452296876286},
#     'eigen-pc': {'phred': 8.147482,
#      'raw': 0.720175393750942,
#      'raw_rankscore': 0.83692},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.75326,
#      'coding_score': 0.97552},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999974230988},
#     'gerp++': {'nr': 5.26, 'rs': 5.26, 'rs_rankscore': 0.73376},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648170, 'start': 54648170},
#     'hg19': {'end': 56361903, 'start': 56361903},
#     'hg38': {'end': 55968119, 'start': 55968119},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.049683,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K89*', 'K63*', 'K89*', 'K89*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 9.248, 'vertebrate_rankscore': 0.9458},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.4595,
#      'logodds_rankscore': 0.66874,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361903, 'start': 56361903},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '505'},
#       'cds': {'length': '897', 'position': '265'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.265A>T',
#       'hgvs_p': 'p.Lys89*',
#       'protein': {'length': '298', 'position': '89'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '427'},
#       'cds': {'length': '717', 'position': '187'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.187A>T',
#       'hgvs_p': 'p.Lys63*',
#       'protein': {'length': '238', 'position': '63'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '505'},
#       'cds': {'length': '795', 'position': '265'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.265A>T',
#       'hgvs_p': 'p.Lys89*',
#       'protein': {'length': '264', 'position': '89'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2057',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2057',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1407',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56361903', 'ref': 'A'}},
#   {'_id': 'chr12:g.56361869C>A',
#    '_score': 7.1632676,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'A',
#     'anc': 'C',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': 1.06, 'mgw': -0.35, 'prot': -3.67, 'roll': -2.25},
#     'encode': {'exp': 683.87,
#      'h3k27ac': 11.52,
#      'h3k4me1': 21.44,
#      'h3k4me3': 26.48,
#      'nucleo': 1.2},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 471,
#       'cds_pos': 231,
#       'rel_cdna_pos': 0.21,
#       'rel_cds_pos': 0.26},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 77, 'rel_prot_pos': 0.26}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 4.36},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 227,
#     'min_dist_tss': 611,
#     'mutindex': -2,
#     'naa': '*',
#     'oaa': 'Y',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.997, 'vertebrate': 1.0},
#     'phred': 36,
#     'phylop': {'mammalian': 1.329, 'primate': 0.486, 'vertebrate': 3.117},
#     'pos': 56361869,
#     'rawscore': 10.033274,
#     'ref': 'C',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 2,
#      'codonpos': 3,
#      'pos': ['77', '77', '51', '77'],
#      'ref': 'Y',
#      'refcodon': 'TAC'},
#     'alt': 'A',
#     'ancestral_allele': 'C',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.82906,
#      'score': 0.9973468632930617},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 6.40465,
#      'raw': 0.644141070663874},
#     'eigen-pc': {'phred': 5.174308,
#      'raw': 0.501693885127163,
#      'raw_rankscore': 0.6821},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.68415,
#      'coding_score': 0.96333},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999937496681},
#     'gerp++': {'nr': 5.26, 'rs': 4.36, 'rs_rankscore': 0.51475},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648136, 'start': 54648136},
#     'hg19': {'end': 56361869, 'start': 56361869},
#     'hg38': {'end': 55968085, 'start': 55968085},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Y77*', 'Y51*', 'Y77*', 'Y77*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 0.999, 'mammalian_rankscore': 0.74975}},
#     'phylo': {'p100way': {'vertebrate': 1.024,
#       'vertebrate_rankscore': 0.29476},
#      'p20way': {'mammalian': 0.038, 'mammalian_rankscore': 0.15345}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'C',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 12.2421,
#      'logodds_rankscore': 0.53681,
#      'pi': {'a': 0.0, 'c': 0.9144, 'g': 0.0, 't': 0.0856}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361869, 'start': 56361869},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '471'},
#       'cds': {'length': '897', 'position': '231'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.231C>A',
#       'hgvs_p': 'p.Tyr77*',
#       'protein': {'length': '298', 'position': '77'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '393'},
#       'cds': {'length': '717', 'position': '153'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.153C>A',
#       'hgvs_p': 'p.Tyr51*',
#       'protein': {'length': '238', 'position': '51'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '471'},
#       'cds': {'length': '795', 'position': '231'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.231C>A',
#       'hgvs_p': 'p.Tyr77*',
#       'protein': {'length': '264', 'position': '77'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2023',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2023',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1373',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'A', 'position': '56361869', 'ref': 'C'}},
#   {'_id': 'chr12:g.56362567T>G',
#    '_score': 7.1632676,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'G',
#     'anc': 'T',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 250,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.071,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.016,
#      'tssaflnk': 0.008,
#      'tssbiv': 0.0,
#      'tx': 0.15,
#      'txflnk': 0.039,
#      'txwk': 0.646,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.03,
#     'dna': {'helt': -1.67, 'mgw': 0.25, 'prot': 2.06, 'roll': 0.17},
#     'dst2splice': 6,
#     'dst2spltype': 'ACCEPTOR',
#     'encode': {'exp': 154.41,
#      'h3k27ac': 7.16,
#      'h3k4me1': 14.12,
#      'h3k4me3': 19.96,
#      'nucleo': 2.8},
#     'exon': '4/7',
#     'fitcons': 0.726386,
#     'gc': 0.52,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 561,
#       'cds_pos': 321,
#       'rel_cdna_pos': 0.24,
#       'rel_cds_pos': 0.36},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 107, 'rel_prot_pos': 0.36}},
#     'gerp': {'n': 4.53, 'rs': 602.1, 'rs_pval': 2.56976e-59, 's': 2.07},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 472,
#     'min_dist_tss': 1321,
#     'mutindex': -13,
#     'naa': '*',
#     'oaa': 'Y',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.961, 'vertebrate': 1.0},
#     'phred': 36,
#     'phylop': {'mammalian': 0.808, 'primate': 0.375, 'vertebrate': 0.429},
#     'pos': 56362567,
#     'rawscore': 9.700482,
#     'ref': 'T',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 2,
#      'codonpos': 3,
#      'pos': ['107', '107', '81', '107'],
#      'ref': 'Y',
#      'refcodon': 'TAT'},
#     'alt': 'G',
#     'ancestral_allele': 'T',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.77255,
#      'score': 0.996532737764271},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 5.131892,
#      'raw': 0.512233895100652},
#     'eigen-pc': {'phred': 3.893138,
#      'raw': 0.329494801375175,
#      'raw_rankscore': 0.57571},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.48831,
#      'coding_score': 0.8894},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.42663, 'score': 0.999765088166355},
#     'gerp++': {'nr': 4.53, 'rs': 2.07, 'rs_rankscore': 0.25882},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54648834, 'start': 54648834},
#     'hg19': {'end': 56362567, 'start': 56362567},
#     'hg38': {'end': 55968783, 'start': 55968783},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.9842,
#      'fitcons_score': 0.735409},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8535,
#      'fitcons_score': 0.722319},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Y107*', 'Y81*', 'Y107*', 'Y107*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 1.715, 'vertebrate_rankscore': 0.3736},
#      'p20way': {'mammalian': 1.004, 'mammalian_rankscore': 0.6225}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'T',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 8.4104,
#      'logodds_rankscore': 0.31622,
#      'pi': {'a': 0.0, 'c': 0.1901, 'g': 0.0, 't': 0.8099}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56362567, 'start': 56362567},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '561'},
#       'cds': {'length': '897', 'position': '321'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.321T>G',
#       'hgvs_p': 'p.Tyr107*',
#       'protein': {'length': '298', 'position': '107'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '483'},
#       'cds': {'length': '717', 'position': '243'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.243T>G',
#       'hgvs_p': 'p.Tyr81*',
#       'protein': {'length': '238', 'position': '81'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '561'},
#       'cds': {'length': '795', 'position': '321'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.321T>G',
#       'hgvs_p': 'p.Tyr107*',
#       'protein': {'length': '264', 'position': '107'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2721',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2721',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2071',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'G', 'position': '56362567', 'ref': 'T'}},
#   {'_id': 'chr12:g.56361900A>T',
#    '_score': 7.123927,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': -0.9, 'mgw': 0.88, 'prot': 3.28, 'roll': 7.71},
#     'encode': {'exp': 708.71,
#      'h3k27ac': 9.44,
#      'h3k4me1': 22.4,
#      'h3k4me3': 24.48,
#      'nucleo': 1.1},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 502,
#       'cds_pos': 262,
#       'rel_cdna_pos': 0.22,
#       'rel_cds_pos': 0.29},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 88, 'rel_prot_pos': 0.3}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 5.26},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 196,
#     'min_dist_tss': 642,
#     'mutindex': -36,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.994, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.122, 'primate': 0.398, 'vertebrate': 4.77},
#     'pos': 56361900,
#     'rawscore': 11.826591,
#     'ref': 'A',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['88', '88', '62', '88'],
#      'ref': 'K',
#      'refcodon': 'AAG'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.76439,
#      'score': 0.9964034676927931},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 9.620236,
#      'raw': 0.840301643323044},
#     'eigen-pc': {'phred': 8.143378,
#      'raw': 0.719973840873594,
#      'raw_rankscore': 0.8367},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.83996,
#      'coding_score': 0.98561},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999997431},
#     'gerp++': {'nr': 5.26, 'rs': 5.26, 'rs_rankscore': 0.73376},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648167, 'start': 54648167},
#     'hg19': {'end': 56361900, 'start': 56361900},
#     'hg38': {'end': 55968116, 'start': 55968116},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K88*', 'K62*', 'K88*', 'K88*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 0.998, 'mammalian_rankscore': 0.69722}},
#     'phylo': {'p100way': {'vertebrate': 9.248, 'vertebrate_rankscore': 0.9458},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.4595,
#      'logodds_rankscore': 0.66874,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361900, 'start': 56361900},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '502'},
#       'cds': {'length': '897', 'position': '262'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.262A>T',
#       'hgvs_p': 'p.Lys88*',
#       'protein': {'length': '298', 'position': '88'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '424'},
#       'cds': {'length': '717', 'position': '184'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.184A>T',
#       'hgvs_p': 'p.Lys62*',
#       'protein': {'length': '238', 'position': '62'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
# ...
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 241,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.094,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.0,
#      'tssaflnk': 0.0,
#      'tssbiv': 0.0,
#      'tx': 0.331,
#      'txflnk': 0.024,
#      'txwk': 0.496,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.05,
#     'dna': {'helt': -0.77, 'mgw': 0.97, 'prot': 2.54, 'roll': 8.9},
#     'encode': {'exp': 822.54,
#      'h3k27ac': 9.84,
#      'h3k4me1': 10.12,
#      'h3k4me3': 6.6,
#      'nucleo': 0.7},
#     'exon': '6/7',
#     'fitcons': 0.701516,
#     'gc': 0.53,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 964,
#       'cds_pos': 724,
#       'rel_cdna_pos': 0.42,
#       'rel_cds_pos': 0.81},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 242, 'rel_prot_pos': 0.81}},
#     'gerp': {'n': 5.12, 'rs': 2645.2, 'rs_pval': 9.82059e-310, 's': 5.12},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 80,
#     'min_dist_tss': 59,
#     'mutindex': -32,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.868, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.066, 'primate': 0.478, 'vertebrate': 4.714},
#     'pos': 56364963,
#     'rawscore': 12.185485,
#     'ref': 'A',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['242', '290', '182', '208'],
#      'ref': 'K',
#      'refcodon': 'AAG'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.72395,
#      'score': 0.9957443054637624},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 8.504234,
#      'raw': 0.785569528099217},
#     'eigen-pc': {'phred': 6.924379,
#      'raw': 0.650882296532907,
#      'raw_rankscore': 0.78559},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBCIJ',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.3842,
#      'coding_score': 0.78455},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999999909},
#     'gerp++': {'nr': 5.12, 'rs': 5.12, 'rs_rankscore': 0.69338},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54651230, 'start': 54651230},
#     'hg19': {'end': 56364963, 'start': 56364963},
#     'hg38': {'end': 55971179, 'start': 55971179},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.83238,
#      'fitcons_score': 0.714379},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.72963,
#      'fitcons_score': 0.706548},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K208*', 'K182*', 'K290*', 'K242*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 4.968,
#       'vertebrate_rankscore': 0.63211},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.2119,
#      'logodds_rankscore': 0.65164,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56364963, 'start': 56364963},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '964'},
#       'cds': {'length': '897', 'position': '724'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.724A>T',
#       'hgvs_p': 'p.Lys242*',
#       'protein': {'length': '298', 'position': '242'},
#       'putative_impact': 'HIGH',
#       'rank': '6',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '784'},
#       'cds': {'length': '717', 'position': '544'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.544A>T',
#       'hgvs_p': 'p.Lys182*',
#       'protein': {'length': '238', 'position': '182'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '862'},
#       'cds': {'length': '795', 'position': '622'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.622A>T',
#       'hgvs_p': 'p.Lys208*',
#       'protein': {'length': '264', 'position': '208'},
#       'putative_impact': 'HIGH',
#       'rank': '5',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2734',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252036.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-181A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '4467',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2832',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252037.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2832',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_002868.3',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56364963', 'ref': 'A'}},
#   {'_id': 'chr12:g.56364920G>A',
#    '_score': 7.0576696,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'A',
#     'anc': 'G',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 241,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.094,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.0,
#      'tssaflnk': 0.0,
#      'tssbiv': 0.0,
#      'tx': 0.331,
#      'txflnk': 0.024,
#      'txwk': 0.496,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.04,
#     'dna': {'helt': -1.87, 'mgw': 0.07, 'prot': 1.32, 'roll': -0.88},
#     'encode': {'exp': 602.32,
#      'h3k27ac': 6.56,
#      'h3k4me1': 11.0,
#      'h3k4me3': 6.0,
#      'nucleo': 2.9},
#     'exon': '6/7',
#     'fitcons': 0.701516,
#     'gc': 0.5,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 921,
#       'cds_pos': 681,
#       'rel_cdna_pos': 0.4,
#       'rel_cds_pos': 0.76},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 227, 'rel_prot_pos': 0.76}},
#     'gerp': {'n': 5.22, 'rs': 2645.2, 'rs_pval': 9.82059e-310, 's': 5.22},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'FALSE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 37,
#     'min_dist_tss': 16,
#     'mutindex': -27,
#     'naa': '*',
#     'oaa': 'W',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.782, 'vertebrate': 1.0},
#     'phred': 37,
#     'phylop': {'mammalian': 2.613, 'primate': 0.587, 'vertebrate': 5.764},
#     'pos': 56364920,
#     'rawscore': 11.158933,
#     'ref': 'G',
#     'segway': 'GE1',
#     'tf': {'bs': 3, 'bs_peaks': 3, 'bs_peaks_max': 115.3137},
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 3,
#      'pos': ['227', '275', '167', '193'],
#      'ref': 'W',
#      'refcodon': 'TGG'},
#     'alt': 'A',
#     'ancestral_allele': 'G',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.50716,
#      'score': 0.9904489076876952},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 11.76209,
#      'raw': 0.926699615331582},
#     'eigen-pc': {'phred': 10.03928,
#      'raw': 0.797126696617316,
#      'raw_rankscore': 0.89252},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFDBHCIJ',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.56866,
#      'coding_score': 0.93022},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.98309, 'score': 1.0},
#     'gerp++': {'nr': 5.22, 'rs': 5.22, 'rs_rankscore': 0.72176},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54651187, 'start': 54651187},
#     'hg19': {'end': 56364920, 'start': 56364920},
#     'hg38': {'end': 55971136, 'start': 55971136},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.83238,
#      'fitcons_score': 0.714379},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.72963,
#      'fitcons_score': 0.706548},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.62918,
#      'omega': 0.062186,
#      'pred': 'D',
#      'score': 1e-06},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['W193*', 'W167*', 'W275*', 'W227*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 8.139,
#       'vertebrate_rankscore': 0.89444},
#      'p20way': {'mammalian': 0.978, 'mammalian_rankscore': 0.59618}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'G',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 17.9463,
#      'logodds_rankscore': 0.88907,
#      'pi': {'a': 0.0, 'c': 0.0, 'g': 1.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56364920, 'start': 56364920},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '921'},
#       'cds': {'length': '897', 'position': '681'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.681G>A',
#       'hgvs_p': 'p.Trp227*',
#       'protein': {'length': '298', 'position': '227'},
#       'putative_impact': 'HIGH',
#       'rank': '6',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '741'},
#       'cds': {'length': '717', 'position': '501'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.501G>A',
#       'hgvs_p': 'p.Trp167*',
#       'protein': {'length': '238', 'position': '167'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '819'},
#       'cds': {'length': '795', 'position': '579'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.579G>A',
#       'hgvs_p': 'p.Trp193*',
#       'protein': {'length': '264', 'position': '193'},
#       'putative_impact': 'HIGH',
#       'rank': '5',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2777',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252036.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-181G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '4424',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87C>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2875',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252037.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2875',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_002868.3',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'A', 'position': '56364920', 'ref': 'G'}}],
#  'max_score': 8.73773,
#  'took': 7,
#  'total': 5687}

# %% [markdown]
# #### Approach 2: Using JSON-LD powered neutral query function

# %%
from biothings_helper import query_biothings

# %%
# Query for a gene symbol CDK2 using URI for gene symbol, which is 'http://identifiers.org/hgnc.symbol/'
query_biothings(api='myvariant.info', fields_uri='http://identifiers.org/hgnc.symbol/', fields_value='CDK2', fetch_all=False)
# Out:
# clinvar.gene.symbol:CDK2 OR docm.genename:CDK2 OR snpeff.nmd.genename:CDK2 OR gwassnps.genename:CDK2 OR dbnsfp.genename:CDK2 OR docm.default_gene_name:CDK2 OR snpeff.ann.genename:CDK2 OR snpeff.lof.genename:CDK2 OR emv.gene.symbol:CDK2 OR dbsnp.gene.symbol:CDK2 OR evs.gene.symbol:CDK2 OR cadd.gene.genename:CDK2
# None
# {'hits': [{'_id': 'chr12:g.56361693G>T',
#    '_score': 8.73773,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'G',
#     'annotype': ['CodingTranscript', 'Intergenic', 'Intergenic'],
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.024,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.039,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.142,
#      'tssaflnk': 0.291,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.063,
#      'txwk': 0.181,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': ['stop_gained', 'upstream', 'upstream'],
#     'consequence': ['STOP_GAINED', 'UPSTREAM', 'UPSTREAM'],
#     'consscore': [8, 1, 1],
#     'cpg': 0.03,
#     'dna': {'helt': 0.43, 'mgw': 0.6, 'prot': -1.24, 'roll': 6.36},
#     'encode': {'exp': 521.18,
#      'h3k27ac': 20.96,
#      'h3k4me1': 29.52,
#      'h3k4me3': 55.04,
#      'nucleo': 2.1},
#     'exon': '2/7',
#     'fitcons': 0.623825,
#     'gc': 0.48,
#     'gene': [{'ccds_id': 'CCDS8898.1',
#       'cds': {'cdna_pos': 409,
#        'cds_pos': 169,
#        'rel_cdna_pos': 0.18,
#        'rel_cds_pos': 0.19},
#       'feature_id': 'ENST00000266970',
#       'gene_id': 'ENSG00000123374',
#       'genename': 'CDK2',
#       'prot': {'domain': 'ndomain', 'protpos': 57, 'rel_prot_pos': 0.19}},
#      {'ccds_id': 'CCDS55834.1',
#       'feature_id': 'ENST00000449260',
#       'gene_id': 'ENSG00000185664',
#       'genename': 'PMEL'},
#      {'feature_id': 'ENST00000554022',
#       'gene_id': 'ENSG00000258554',
#       'genename': 'RP11-973D8.4'}],
#     'gerp': {'n': 4.73, 'rs': 406.8, 'rs_pval': 1.65278e-39, 's': 4.73},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 403,
#     'min_dist_tss': 435,
#     'mutindex': -42,
#     'naa': '*',
#     'oaa': 'E',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.996, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.626, 'primate': 0.486, 'vertebrate': 5.559},
#     'pos': 56361693,
#     'rawscore': 11.874943,
#     'ref': 'G',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': 57,
#      'ref': 'E',
#      'refcodon': 'GAG'},
#     'alt': 'T',
#     'ancestral_allele': 'G',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.7981,
#      'score': 0.9969183004977041},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 22.49633,
#      'raw': 1.18564590828305},
#     'eigen-pc': {'phred': 20.46959,
#      'raw': 1.02513172599092,
#      'raw_rankscore': 0.9855},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970', 'ENSP00000452514', 'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000354056']},
#     'exac': {'ac': 1,
#      'adj_ac': 1,
#      'adj_af': 8.238e-06,
#      'af': 8.236e-06,
#      'afr_ac': 0,
#      'afr_af': 0,
#      'amr_ac': 0,
#      'amr_af': 0,
#      'eas_ac': 0,
#      'eas_af': 0,
#      'fin_ac': 0,
#      'fin_af': 0,
#      'nfe_ac': 1,
#      'nfe_af': 1.499e-05,
#      'sas_ac': 0,
#      'sas_af': 0},
#     'exac_nontcga': {'ac': 1,
#      'adj_ac': 1,
#      'adj_af': 9.417e-06,
#      'af': 9.415e-06,
#      'afr_ac': 0,
#      'afr_af': 0,
#      'amr_ac': 0,
#      'amr_af': 0,
#      'eas_ac': 0,
#      'eas_af': 0,
#      'fin_ac': 0,
#      'fin_af': 0,
#      'nfe_ac': 1,
#      'nfe_af': 1.84e-05,
#      'sas_ac': 0,
#      'sas_af': 0},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBCI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.70836,
#      'coding_score': 0.96805},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999999985},
#     'gerp++': {'nr': 4.73, 'rs': 4.73, 'rs_rankscore': 0.59331},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54647960, 'start': 54647960},
#     'hg19': {'end': 56361693, 'start': 56361693},
#     'hg38': {'end': 55967909, 'start': 55967909},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': 'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain',
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['E57*', 'E57*', 'E57*', '.'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'without_aae'],
#      'pred': ['A', 'A', 'A', 'D'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 9.985,
#       'vertebrate_rankscore': 0.99176},
#      'p20way': {'mammalian': 0.978, 'mammalian_rankscore': 0.59618}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'G',
#     'rsid': 'rs757201758',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 17.0098,
#      'logodds_rankscore': 0.86213,
#      'pi': {'a': 0.0, 'c': 0.0, 'g': 1.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'dbsnp': {'allele_origin': 'unspecified',
#     'alleles': [{'allele': 'G'}, {'allele': 'T'}],
#     'alt': 'T',
#     'chrom': '12',
#     'class': 'SNV',
#     'dbsnp_build': 144,
#     'flags': ['ASP', 'INT', 'NSN', 'R5', 'REF'],
#     'gene': [{'geneid': '1017', 'symbol': 'CDK2'},
#      {'geneid': '6490', 'symbol': 'PMEL'}],
#     'hg19': {'end': 56361693, 'start': 56361693},
#     'ref': 'G',
#     'rsid': 'rs757201758',
#     'validated': False,
#     'var_subtype': 'tv',
#     'vartype': 'snp'},
#    'exac': {'ac': {'ac': 1,
#      'ac_adj': 1,
#      'ac_afr': 0,
#      'ac_amr': 0,
#      'ac_eas': 0,
#      'ac_female': 1,
#      'ac_fin': 0,
#      'ac_het': 1,
#      'ac_hom': 0,
#      'ac_male': 0,
#      'ac_nfe': 1,
#      'ac_oth': 0,
#      'ac_sas': 0},
#     'af': 8.236e-06,
#     'alleles': 'T',
#     'alt': 'T',
#     'an': {'an': 121412,
#      'an_adj': 121396,
#      'an_afr': 10406,
#      'an_amr': 11572,
#      'an_eas': 8654,
#      'an_female': 54114,
#      'an_fin': 6614,
#      'an_male': 67282,
#      'an_nfe': 66732,
#      'an_oth': 906,
#      'an_sas': 16512},
#     'baseqranksum': -2.257,
#     'chrom': 12,
#     'clippingranksum': -0.394,
#     'culprit': 'MQRankSum',
#     'fs': 2.112,
#     'het': {'het_afr': 0,
#      'het_amr': 0,
#      'het_eas': 0,
#      'het_fin': 0,
#      'het_nfe': 1,
#      'het_oth': 0,
#      'het_sas': 0},
#     'hom': {'hom_afr': 0,
#      'hom_amr': 0,
#      'hom_eas': 0,
#      'hom_fin': 0,
#      'hom_nfe': 0,
#      'hom_oth': 0,
#      'hom_sas': 0},
#     'inbreedingcoeff': 0.0004,
#     'mq': {'mq': 59.71, 'mq0': 0, 'mqranksum': -0.856},
#     'ncc': 7,
#     'pos': 56361693,
#     'qd': 11.01,
#     'readposranksum': 0.802,
#     'ref': 'G',
#     'type': 'snp',
#     'vqslod': 0.69},
#    'exac_nontcga': {'ac': {'ac': 1,
#      'ac_adj': 1,
#      'ac_afr': 0,
#      'ac_amr': 0,
#      'ac_eas': 0,
#      'ac_female': 1,
#      'ac_fin': 0,
#      'ac_het': 1,
#      'ac_hom': 0,
#      'ac_male': 0,
#      'ac_nfe': 1,
#      'ac_oth': 0,
#      'ac_sas': 0},
#     'af': 9.415e-06,
#     'alleles': 'T',
#     'alt': 'T',
#     'an': {'an': 106210,
#      'an_adj': 106196,
#      'an_afr': 9066,
#      'an_amr': 11210,
#      'an_eas': 7866,
#      'an_female': 45866,
#      'an_fin': 6614,
#      'an_male': 60330,
#      'an_nfe': 54338,
#      'an_oth': 694,
#      'an_sas': 16408},
#     'baseqranksum': -2.257,
#     'chrom': 12,
#     'clippingranksum': -0.394,
#     'culprit': 'MQRankSum',
#     'fs': 2.112,
#     'het': {'het_afr': 0,
#      'het_amr': 0,
#      'het_eas': 0,
#      'het_fin': 0,
#      'het_nfe': 1,
#      'het_oth': 0,
#      'het_sas': 0},
#     'hom': {'hom_afr': 0,
#      'hom_amr': 0,
#      'hom_eas': 0,
#      'hom_fin': 0,
#      'hom_nfe': 0,
#      'hom_oth': 0,
#      'hom_sas': 0},
#     'inbreedingcoeff': 0.0004,
#     'mq': {'mq': 59.71, 'mq0': 0, 'mqranksum': -0.856},
#     'ncc': 7,
#     'pos': 56361693,
#     'qd': 11.01,
#     'readposranksum': 0.802,
#     'ref': 'G',
#     'type': 'snp',
#     'vqslod': 0.69},
#    'hg19': {'end': 56361693, 'start': 56361693},
#    'observed': True,
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '409'},
#       'cds': {'length': '897', 'position': '169'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.169G>T',
#       'hgvs_p': 'p.Glu57*',
#       'protein': {'length': '298', 'position': '57'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '409'},
#       'cds': {'length': '795', 'position': '169'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.169G>T',
#       'hgvs_p': 'p.Glu57*',
#       'protein': {'length': '264', 'position': '57'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1847',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1847',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1197',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87C>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'effect': 'intron_variant',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.117-140G>T',
#       'putative_impact': 'MODIFIER',
#       'rank': '1',
#       'total': '4',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '0.67'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '0.67'}},
#    'vcf': {'alt': 'T', 'position': '56361693', 'ref': 'G'}},
#   {'_id': 'chr12:g.56362574C>T',
#    '_score': 7.2263837,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'C',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 250,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.071,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.016,
#      'tssaflnk': 0.008,
#      'tssbiv': 0.0,
#      'tx': 0.15,
#      'txflnk': 0.039,
#      'txwk': 0.646,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.03,
#     'dna': {'helt': 1.21, 'mgw': 0.62, 'prot': -2.97, 'roll': 1.34},
#     'dst2splice': 13,
#     'dst2spltype': 'ACCEPTOR',
#     'encode': {'exp': 193.32,
#      'h3k27ac': 7.16,
#      'h3k4me1': 14.12,
#      'h3k4me3': 19.96,
#      'nucleo': 2.2},
#     'exon': '4/7',
#     'fitcons': 0.726386,
#     'gc': 0.5,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 568,
#       'cds_pos': 328,
#       'rel_cdna_pos': 0.25,
#       'rel_cds_pos': 0.37},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 110, 'rel_prot_pos': 0.37}},
#     'gerp': {'n': 4.53, 'rs': 602.1, 'rs_pval': 2.56976e-59, 's': 4.53},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'FALSE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 479,
#     'min_dist_tss': 1328,
#     'mutindex': -26,
#     'naa': '*',
#     'oaa': 'Q',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.985, 'vertebrate': 1.0},
#     'phred': 39,
#     'phylop': {'mammalian': 2.522, 'primate': 0.457, 'vertebrate': 5.459},
#     'pos': 56362574,
#     'rawscore': 12.632847,
#     'ref': 'C',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['110', '110', '84', '110'],
#      'ref': 'Q',
#      'refcodon': 'CAG'},
#     'alt': 'T',
#     'ancestral_allele': 'C',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.89712,
#      'score': 0.9981459634050125},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 17.64166,
#      'raw': 1.10312033626684},
#     'eigen-pc': {'phred': 15.25602,
#      'raw': 0.933325513156562,
#      'raw_rankscore': 0.96387},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.77402,
#      'coding_score': 0.97845},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.99999999999996},
#     'gerp++': {'nr': 4.53, 'rs': 4.53, 'rs_rankscore': 0.54846},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54648841, 'start': 54648841},
#     'hg19': {'end': 56362574, 'start': 56362574},
#     'hg38': {'end': 55968790, 'start': 55968790},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.9842,
#      'fitcons_score': 0.735409},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8535,
#      'fitcons_score': 0.722319},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Q110*', 'Q84*', 'Q110*', 'Q110*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 7.866,
#       'vertebrate_rankscore': 0.85362},
#      'p20way': {'mammalian': 0.886, 'mammalian_rankscore': 0.38909}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'C',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 16.5654,
#      'logodds_rankscore': 0.84367,
#      'pi': {'a': 0.0, 'c': 1.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56362574, 'start': 56362574},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '568'},
#       'cds': {'length': '897', 'position': '328'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.328C>T',
#       'hgvs_p': 'p.Gln110*',
#       'protein': {'length': '298', 'position': '110'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '490'},
#       'cds': {'length': '717', 'position': '250'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.250C>T',
#       'hgvs_p': 'p.Gln84*',
#       'protein': {'length': '238', 'position': '84'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '568'},
#       'cds': {'length': '795', 'position': '328'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.328C>T',
#       'hgvs_p': 'p.Gln110*',
#       'protein': {'length': '264', 'position': '110'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2728',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2728',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2078',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56362574', 'ref': 'C'}},
#   {'_id': 'chr12:g.56361903A>T',
#    '_score': 7.2185206,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': -3.16, 'mgw': 2.28, 'prot': 4.14, 'roll': 13.24},
#     'encode': {'exp': 696.29,
#      'h3k27ac': 10.16,
#      'h3k4me1': 19.92,
#      'h3k4me3': 29.88,
#      'nucleo': 1.1},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 505,
#       'cds_pos': 265,
#       'rel_cdna_pos': 0.22,
#       'rel_cds_pos': 0.3},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 89, 'rel_prot_pos': 0.3}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 5.26},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 193,
#     'min_dist_tss': 645,
#     'mutindex': -43,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.995, 'vertebrate': 1.0},
#     'phred': 40,
#     'phylop': {'mammalian': 2.122, 'primate': 0.398, 'vertebrate': 3.1},
#     'pos': 56361903,
#     'rawscore': 12.734282,
#     'ref': 'A',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['89', '89', '63', '89'],
#      'ref': 'K',
#      'refcodon': 'AAA'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.72936,
#      'score': 0.9958366694956521},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 9.623577,
#      'raw': 0.840452296876286},
#     'eigen-pc': {'phred': 8.147482,
#      'raw': 0.720175393750942,
#      'raw_rankscore': 0.83692},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.75326,
#      'coding_score': 0.97552},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999974230988},
#     'gerp++': {'nr': 5.26, 'rs': 5.26, 'rs_rankscore': 0.73376},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648170, 'start': 54648170},
#     'hg19': {'end': 56361903, 'start': 56361903},
#     'hg38': {'end': 55968119, 'start': 55968119},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.049683,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K89*', 'K63*', 'K89*', 'K89*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 9.248, 'vertebrate_rankscore': 0.9458},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.4595,
#      'logodds_rankscore': 0.66874,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361903, 'start': 56361903},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '505'},
#       'cds': {'length': '897', 'position': '265'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.265A>T',
#       'hgvs_p': 'p.Lys89*',
#       'protein': {'length': '298', 'position': '89'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '427'},
#       'cds': {'length': '717', 'position': '187'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.187A>T',
#       'hgvs_p': 'p.Lys63*',
#       'protein': {'length': '238', 'position': '63'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '505'},
#       'cds': {'length': '795', 'position': '265'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.265A>T',
#       'hgvs_p': 'p.Lys89*',
#       'protein': {'length': '264', 'position': '89'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2057',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2057',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1407',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56361903', 'ref': 'A'}},
#   {'_id': 'chr12:g.56361869C>A',
#    '_score': 7.1632676,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'A',
#     'anc': 'C',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': 1.06, 'mgw': -0.35, 'prot': -3.67, 'roll': -2.25},
#     'encode': {'exp': 683.87,
#      'h3k27ac': 11.52,
#      'h3k4me1': 21.44,
#      'h3k4me3': 26.48,
#      'nucleo': 1.2},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 471,
#       'cds_pos': 231,
#       'rel_cdna_pos': 0.21,
#       'rel_cds_pos': 0.26},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 77, 'rel_prot_pos': 0.26}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 4.36},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 227,
#     'min_dist_tss': 611,
#     'mutindex': -2,
#     'naa': '*',
#     'oaa': 'Y',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.997, 'vertebrate': 1.0},
#     'phred': 36,
#     'phylop': {'mammalian': 1.329, 'primate': 0.486, 'vertebrate': 3.117},
#     'pos': 56361869,
#     'rawscore': 10.033274,
#     'ref': 'C',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 2,
#      'codonpos': 3,
#      'pos': ['77', '77', '51', '77'],
#      'ref': 'Y',
#      'refcodon': 'TAC'},
#     'alt': 'A',
#     'ancestral_allele': 'C',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.82906,
#      'score': 0.9973468632930617},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 6.40465,
#      'raw': 0.644141070663874},
#     'eigen-pc': {'phred': 5.174308,
#      'raw': 0.501693885127163,
#      'raw_rankscore': 0.6821},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.68415,
#      'coding_score': 0.96333},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999937496681},
#     'gerp++': {'nr': 5.26, 'rs': 4.36, 'rs_rankscore': 0.51475},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648136, 'start': 54648136},
#     'hg19': {'end': 56361869, 'start': 56361869},
#     'hg38': {'end': 55968085, 'start': 55968085},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Y77*', 'Y51*', 'Y77*', 'Y77*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 0.999, 'mammalian_rankscore': 0.74975}},
#     'phylo': {'p100way': {'vertebrate': 1.024,
#       'vertebrate_rankscore': 0.29476},
#      'p20way': {'mammalian': 0.038, 'mammalian_rankscore': 0.15345}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'C',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 12.2421,
#      'logodds_rankscore': 0.53681,
#      'pi': {'a': 0.0, 'c': 0.9144, 'g': 0.0, 't': 0.0856}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361869, 'start': 56361869},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '471'},
#       'cds': {'length': '897', 'position': '231'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.231C>A',
#       'hgvs_p': 'p.Tyr77*',
#       'protein': {'length': '298', 'position': '77'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '393'},
#       'cds': {'length': '717', 'position': '153'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.153C>A',
#       'hgvs_p': 'p.Tyr51*',
#       'protein': {'length': '238', 'position': '51'},
#       'putative_impact': 'HIGH',
#       'rank': '2',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '471'},
#       'cds': {'length': '795', 'position': '231'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.231C>A',
#       'hgvs_p': 'p.Tyr77*',
#       'protein': {'length': '264', 'position': '77'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2023',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2023',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '1373',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87G>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'A', 'position': '56361869', 'ref': 'C'}},
#   {'_id': 'chr12:g.56362567T>G',
#    '_score': 7.1632676,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'G',
#     'anc': 'T',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 250,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.071,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.016,
#      'tssaflnk': 0.008,
#      'tssbiv': 0.0,
#      'tx': 0.15,
#      'txflnk': 0.039,
#      'txwk': 0.646,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.03,
#     'dna': {'helt': -1.67, 'mgw': 0.25, 'prot': 2.06, 'roll': 0.17},
#     'dst2splice': 6,
#     'dst2spltype': 'ACCEPTOR',
#     'encode': {'exp': 154.41,
#      'h3k27ac': 7.16,
#      'h3k4me1': 14.12,
#      'h3k4me3': 19.96,
#      'nucleo': 2.8},
#     'exon': '4/7',
#     'fitcons': 0.726386,
#     'gc': 0.52,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 561,
#       'cds_pos': 321,
#       'rel_cdna_pos': 0.24,
#       'rel_cds_pos': 0.36},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 107, 'rel_prot_pos': 0.36}},
#     'gerp': {'n': 4.53, 'rs': 602.1, 'rs_pval': 2.56976e-59, 's': 2.07},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 472,
#     'min_dist_tss': 1321,
#     'mutindex': -13,
#     'naa': '*',
#     'oaa': 'Y',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.961, 'vertebrate': 1.0},
#     'phred': 36,
#     'phylop': {'mammalian': 0.808, 'primate': 0.375, 'vertebrate': 0.429},
#     'pos': 56362567,
#     'rawscore': 9.700482,
#     'ref': 'T',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 2,
#      'codonpos': 3,
#      'pos': ['107', '107', '81', '107'],
#      'ref': 'Y',
#      'refcodon': 'TAT'},
#     'alt': 'G',
#     'ancestral_allele': 'T',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.77255,
#      'score': 0.996532737764271},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 5.131892,
#      'raw': 0.512233895100652},
#     'eigen-pc': {'phred': 3.893138,
#      'raw': 0.329494801375175,
#      'raw_rankscore': 0.57571},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBI',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.48831,
#      'coding_score': 0.8894},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.42663, 'score': 0.999765088166355},
#     'gerp++': {'nr': 4.53, 'rs': 2.07, 'rs_rankscore': 0.25882},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54648834, 'start': 54648834},
#     'hg19': {'end': 56362567, 'start': 56362567},
#     'hg38': {'end': 55968783, 'start': 55968783},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.9842,
#      'fitcons_score': 0.735409},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8535,
#      'fitcons_score': 0.722319},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['Y107*', 'Y81*', 'Y107*', 'Y107*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 1.715, 'vertebrate_rankscore': 0.3736},
#      'p20way': {'mammalian': 1.004, 'mammalian_rankscore': 0.6225}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'T',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 8.4104,
#      'logodds_rankscore': 0.31622,
#      'pi': {'a': 0.0, 'c': 0.1901, 'g': 0.0, 't': 0.8099}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56362567, 'start': 56362567},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '561'},
#       'cds': {'length': '897', 'position': '321'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.321T>G',
#       'hgvs_p': 'p.Tyr107*',
#       'protein': {'length': '298', 'position': '107'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '483'},
#       'cds': {'length': '717', 'position': '243'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.243T>G',
#       'hgvs_p': 'p.Tyr81*',
#       'protein': {'length': '238', 'position': '81'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '561'},
#       'cds': {'length': '795', 'position': '321'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.321T>G',
#       'hgvs_p': 'p.Tyr107*',
#       'protein': {'length': '264', 'position': '107'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2721',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200054.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2721',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001200053.1',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-52A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2071',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87A>C',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'G', 'position': '56362567', 'ref': 'T'}},
#   {'_id': 'chr12:g.56361900A>T',
#    '_score': 7.123927,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'T',
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 251,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.055,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.047,
#      'tssaflnk': 0.094,
#      'tssbiv': 0.0,
#      'tx': 0.0,
#      'txflnk': 0.11,
#      'txwk': 0.457,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.0,
#     'dna': {'helt': -0.9, 'mgw': 0.88, 'prot': 3.28, 'roll': 7.71},
#     'encode': {'exp': 708.71,
#      'h3k27ac': 9.44,
#      'h3k4me1': 22.4,
#      'h3k4me3': 24.48,
#      'nucleo': 1.1},
#     'exon': '3/7',
#     'fitcons': 0.623825,
#     'gc': 0.44,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 502,
#       'cds_pos': 262,
#       'rel_cdna_pos': 0.22,
#       'rel_cds_pos': 0.29},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 88, 'rel_prot_pos': 0.3}},
#     'gerp': {'n': 5.26, 'rs': 504.2, 'rs_pval': 6.27736e-64, 's': 5.26},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 196,
#     'min_dist_tss': 642,
#     'mutindex': -36,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.994, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.122, 'primate': 0.398, 'vertebrate': 4.77},
#     'pos': 56361900,
#     'rawscore': 11.826591,
#     'ref': 'A',
#     'segway': 'E/GM',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['88', '88', '62', '88'],
#      'ref': 'K',
#      'refcodon': 'AAG'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.76439,
#      'score': 0.9964034676927931},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 9.620236,
#      'raw': 0.840301643323044},
#     'eigen-pc': {'phred': 8.143378,
#      'raw': 0.719973840873594,
#      'raw_rankscore': 0.8367},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFB',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.83996,
#      'coding_score': 0.98561},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999997431},
#     'gerp++': {'nr': 5.26, 'rs': 5.26, 'rs_rankscore': 0.73376},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.61804,
#      'fitcons_score': 0.685571},
#     'hg18': {'end': 54648167, 'start': 54648167},
#     'hg19': {'end': 56361900, 'start': 56361900},
#     'hg38': {'end': 55968116, 'start': 55968116},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.59914,
#      'fitcons_score': 0.651492},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.49028,
#      'fitcons_score': 0.660085},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K88*', 'K62*', 'K88*', 'K88*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 0.998, 'mammalian_rankscore': 0.69722}},
#     'phylo': {'p100way': {'vertebrate': 9.248, 'vertebrate_rankscore': 0.9458},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.4595,
#      'logodds_rankscore': 0.66874,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56361900, 'start': 56361900},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '502'},
#       'cds': {'length': '897', 'position': '262'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.262A>T',
#       'hgvs_p': 'p.Lys88*',
#       'protein': {'length': '298', 'position': '88'},
#       'putative_impact': 'HIGH',
#       'rank': '3',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '424'},
#       'cds': {'length': '717', 'position': '184'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
# ...
#     'anc': 'A',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 241,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.094,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.0,
#      'tssaflnk': 0.0,
#      'tssbiv': 0.0,
#      'tx': 0.331,
#      'txflnk': 0.024,
#      'txwk': 0.496,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.05,
#     'dna': {'helt': -0.77, 'mgw': 0.97, 'prot': 2.54, 'roll': 8.9},
#     'encode': {'exp': 822.54,
#      'h3k27ac': 9.84,
#      'h3k4me1': 10.12,
#      'h3k4me3': 6.6,
#      'nucleo': 0.7},
#     'exon': '6/7',
#     'fitcons': 0.701516,
#     'gc': 0.53,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 964,
#       'cds_pos': 724,
#       'rel_cdna_pos': 0.42,
#       'rel_cds_pos': 0.81},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 242, 'rel_prot_pos': 0.81}},
#     'gerp': {'n': 5.12, 'rs': 2645.2, 'rs_pval': 9.82059e-310, 's': 5.12},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'TRUE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 80,
#     'min_dist_tss': 59,
#     'mutindex': -32,
#     'naa': '*',
#     'oaa': 'K',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.868, 'vertebrate': 1.0},
#     'phred': 38,
#     'phylop': {'mammalian': 2.066, 'primate': 0.478, 'vertebrate': 4.714},
#     'pos': 56364963,
#     'rawscore': 12.185485,
#     'ref': 'A',
#     'segway': 'GE1',
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 1,
#      'pos': ['242', '290', '182', '208'],
#      'ref': 'K',
#      'refcodon': 'AAG'},
#     'alt': 'T',
#     'ancestral_allele': 'A',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.72395,
#      'score': 0.9957443054637624},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 8.504234,
#      'raw': 0.785569528099217},
#     'eigen-pc': {'phred': 6.924379,
#      'raw': 0.650882296532907,
#      'raw_rankscore': 0.78559},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFBCIJ',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.3842,
#      'coding_score': 0.78455},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.74713, 'score': 0.999999999999909},
#     'gerp++': {'nr': 5.12, 'rs': 5.12, 'rs_rankscore': 0.69338},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54651230, 'start': 54651230},
#     'hg19': {'end': 56364963, 'start': 56364963},
#     'hg38': {'end': 55971179, 'start': 55971179},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.83238,
#      'fitcons_score': 0.714379},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.72963,
#      'fitcons_score': 0.706548},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.84324,
#      'omega': 0.0,
#      'pred': 'D',
#      'score': 0.0},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['K208*', 'K182*', 'K290*', 'K242*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 4.968,
#       'vertebrate_rankscore': 0.63211},
#      'p20way': {'mammalian': 1.118, 'mammalian_rankscore': 0.88034}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'A',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 14.2119,
#      'logodds_rankscore': 0.65164,
#      'pi': {'a': 1.0, 'c': 0.0, 'g': 0.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56364963, 'start': 56364963},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '964'},
#       'cds': {'length': '897', 'position': '724'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.724A>T',
#       'hgvs_p': 'p.Lys242*',
#       'protein': {'length': '298', 'position': '242'},
#       'putative_impact': 'HIGH',
#       'rank': '6',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '784'},
#       'cds': {'length': '717', 'position': '544'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.544A>T',
#       'hgvs_p': 'p.Lys182*',
#       'protein': {'length': '238', 'position': '182'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '862'},
#       'cds': {'length': '795', 'position': '622'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.622A>T',
#       'hgvs_p': 'p.Lys208*',
#       'protein': {'length': '264', 'position': '208'},
#       'putative_impact': 'HIGH',
#       'rank': '5',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2734',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252036.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-181A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '4467',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87T>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2832',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252037.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2832',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_002868.3',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222A>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'T', 'position': '56364963', 'ref': 'A'}},
#   {'_id': 'chr12:g.56364920G>A',
#    '_score': 7.0576696,
#    'cadd': {'_license': 'http://goo.gl/bkpNhq',
#     'alt': 'A',
#     'anc': 'G',
#     'annotype': 'CodingTranscript',
#     'bstatistic': 241,
#     'chmm': {'bivflnk': 0.0,
#      'enh': 0.094,
#      'enhbiv': 0.0,
#      'het': 0.0,
#      'quies': 0.055,
#      'reprpc': 0.0,
#      'reprpcwk': 0.0,
#      'tssa': 0.0,
#      'tssaflnk': 0.0,
#      'tssbiv': 0.0,
#      'tx': 0.331,
#      'txflnk': 0.024,
#      'txwk': 0.496,
#      'znfrpts': 0.0},
#     'chrom': 12,
#     'consdetail': 'stop_gained',
#     'consequence': 'STOP_GAINED',
#     'consscore': 8,
#     'cpg': 0.04,
#     'dna': {'helt': -1.87, 'mgw': 0.07, 'prot': 1.32, 'roll': -0.88},
#     'encode': {'exp': 602.32,
#      'h3k27ac': 6.56,
#      'h3k4me1': 11.0,
#      'h3k4me3': 6.0,
#      'nucleo': 2.9},
#     'exon': '6/7',
#     'fitcons': 0.701516,
#     'gc': 0.5,
#     'gene': {'ccds_id': 'CCDS8898.1',
#      'cds': {'cdna_pos': 921,
#       'cds_pos': 681,
#       'rel_cdna_pos': 0.4,
#       'rel_cds_pos': 0.76},
#      'feature_id': 'ENST00000266970',
#      'gene_id': 'ENSG00000123374',
#      'genename': 'CDK2',
#      'prot': {'domain': 'ndomain', 'protpos': 227, 'rel_prot_pos': 0.76}},
#     'gerp': {'n': 5.22, 'rs': 2645.2, 'rs_pval': 9.82059e-310, 's': 5.22},
#     'isderived': 'TRUE',
#     'isknownvariant': 'FALSE',
#     'istv': 'FALSE',
#     'length': 0,
#     'mapability': {'20bp': 1, '35bp': 1},
#     'min_dist_tse': 37,
#     'min_dist_tss': 16,
#     'mutindex': -27,
#     'naa': '*',
#     'oaa': 'W',
#     'phast_cons': {'mammalian': 1.0, 'primate': 0.782, 'vertebrate': 1.0},
#     'phred': 37,
#     'phylop': {'mammalian': 2.613, 'primate': 0.587, 'vertebrate': 5.764},
#     'pos': 56364920,
#     'rawscore': 11.158933,
#     'ref': 'G',
#     'segway': 'GE1',
#     'tf': {'bs': 3, 'bs_peaks': 3, 'bs_peaks_max': 115.3137},
#     'type': 'SNV'},
#    'chrom': '12',
#    'dbnsfp': {'aa': {'alt': 'X',
#      'codon_degeneracy': 0,
#      'codonpos': 3,
#      'pos': ['227', '275', '167', '193'],
#      'ref': 'W',
#      'refcodon': 'TGG'},
#     'alt': 'A',
#     'ancestral_allele': 'G',
#     'cds_strand': '+',
#     'chrom': '12',
#     'dann': {'_license': 'https://goo.gl/IeLhCq',
#      'rankscore': 0.50716,
#      'score': 0.9904489076876952},
#     'eigen': {'coding_or_noncoding': 'c',
#      'phred': 11.76209,
#      'raw': 0.926699615331582},
#     'eigen-pc': {'phred': 10.03928,
#      'raw': 0.797126696617316,
#      'raw_rankscore': 0.89252},
#     'ensembl': {'geneid': 'ENSG00000123374',
#      'proteinid': ['ENSP00000266970',
#       'ENSP00000452514',
#       'ENSP00000393605',
#       'ENSP00000243067'],
#      'transcriptid': ['ENST00000266970',
#       'ENST00000553376',
#       'ENST00000440311',
#       'ENST00000354056']},
#     'fathmm': {'score': None},
#     'fathmm-mkl': {'coding_group': 'AEFDBHCIJ',
#      'coding_pred': 'D',
#      'coding_rankscore': 0.56866,
#      'coding_score': 0.93022},
#     'genename': 'CDK2',
#     'genocanyon': {'rankscore': 0.98309, 'score': 1.0},
#     'gerp++': {'nr': 5.22, 'rs': 5.22, 'rs_rankscore': 0.72176},
#     'gm12878': {'confidence_value': 0,
#      'fitcons_rankscore': 0.65041,
#      'fitcons_score': 0.672317},
#     'h1-hesc': {'confidence_value': 0,
#      'fitcons_rankscore': 0.8784,
#      'fitcons_score': 0.724815},
#     'hg18': {'end': 54651187, 'start': 54651187},
#     'hg19': {'end': 56364920, 'start': 56364920},
#     'hg38': {'end': 55971136, 'start': 55971136},
#     'huvec': {'confidence_value': 0,
#      'fitcons_rankscore': 0.83238,
#      'fitcons_score': 0.714379},
#     'integrated': {'confidence_value': 0,
#      'fitcons_rankscore': 0.72963,
#      'fitcons_score': 0.706548},
#     'interpro_domain': ['Protein kinase domain|Protein kinase-like domain',
#      'Protein kinase domain|Protein kinase-like domain|Serine/threonine/dual specificity protein kinase, catalytic  domain'],
#     'lrt': {'converted_rankscore': 0.62918,
#      'omega': 0.062186,
#      'pred': 'D',
#      'score': 1e-06},
#     'm_cap_score': {'score': None},
#     'metalr': {'score': None},
#     'metasvm': {'score': None},
#     'mutationassessor': {'score': None},
#     'mutationtaster': {'AAE': ['W193*', 'W167*', 'W275*', 'W227*'],
#      'converted_rankscore': 0.81033,
#      'model': ['complex_aae', 'complex_aae', 'complex_aae', 'complex_aae'],
#      'pred': ['A', 'A', 'A', 'A'],
#      'score': [1, 1, 1, 1]},
#     'phastcons': {'100way': {'vertebrate': 1.0,
#       'vertebrate_rankscore': 0.71511},
#      '20way': {'mammalian': 1.0, 'mammalian_rankscore': 0.88762}},
#     'phylo': {'p100way': {'vertebrate': 8.139,
#       'vertebrate_rankscore': 0.89444},
#      'p20way': {'mammalian': 0.978, 'mammalian_rankscore': 0.59618}},
#     'polyphen2': {'_license': 'http://goo.gl/6Cz4Ae',
#      'hdiv': {'score': None},
#      'hvar': {'score': None}},
#     'provean': {'score': None},
#     'ref': 'G',
#     'sift': {'score': None},
#     'siphy_29way': {'logodds': 17.9463,
#      'logodds_rankscore': 0.88907,
#      'pi': {'a': 0.0, 'c': 0.0, 'g': 1.0, 't': 0.0}},
#     'vest3': {'_license': 'http://goo.gl/jTko4F', 'score': None}},
#    'hg19': {'end': 56364920, 'start': 56364920},
#    'snpeff': {'ann': [{'cdna': {'length': '2301', 'position': '921'},
#       'cds': {'length': '897', 'position': '681'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001798.4',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.681G>A',
#       'hgvs_p': 'p.Trp227*',
#       'protein': {'length': '298', 'position': '227'},
#       'putative_impact': 'HIGH',
#       'rank': '6',
#       'total': '7',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2121', 'position': '741'},
#       'cds': {'length': '717', 'position': '501'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_001290230.1',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.501G>A',
#       'hgvs_p': 'p.Trp167*',
#       'protein': {'length': '238', 'position': '167'},
#       'putative_impact': 'HIGH',
#       'rank': '4',
#       'total': '5',
#       'transcript_biotype': 'Coding'},
#      {'cdna': {'length': '2199', 'position': '819'},
#       'cds': {'length': '795', 'position': '579'},
#       'effect': 'stop_gained',
#       'feature_id': 'NM_052827.3',
#       'feature_type': 'transcript',
#       'gene_id': 'CDK2',
#       'genename': 'CDK2',
#       'hgvs_c': 'c.579G>A',
#       'hgvs_p': 'p.Trp193*',
#       'protein': {'length': '264', 'position': '193'},
#       'putative_impact': 'HIGH',
#       'rank': '5',
#       'total': '6',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2777',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252036.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-181G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '4424',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_006928.4',
#       'feature_type': 'transcript',
#       'gene_id': 'PMEL',
#       'genename': 'PMEL',
#       'hgvs_c': 'c.-87C>T',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2875',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_001252037.1',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'},
#      {'distance_to_feature': '2875',
#       'effect': 'upstream_gene_variant',
#       'feature_id': 'NM_002868.3',
#       'feature_type': 'transcript',
#       'gene_id': 'RAB5B',
#       'genename': 'RAB5B',
#       'hgvs_c': 'c.-222G>A',
#       'putative_impact': 'MODIFIER',
#       'transcript_biotype': 'Coding'}],
#     'lof': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'},
#     'nmd': {'gene_id': 'CDK2',
#      'genename': 'CDK2',
#      'number_of_transcripts_in_gene': '3',
#      'percent_of_transcripts_affected': '1.00'}},
#    'vcf': {'alt': 'A', 'position': '56364920', 'ref': 'G'}}],
#  'max_score': 8.73773,
#  'took': 34,
#  'total': 5687}

# %% [markdown]
# # 2. Facilitate API Cross Linking

# %% [markdown]
# ##### Use Case Scenario: Upstream analysis identified a missense variant (chr8:g.99440236C>A). The analyst wants to obtain the matching InterPro data in order to assess the likely functional significance of this variant.

# %% [markdown]
# #### Step 1: Query MyVariant.info to retrieve the annotation object for variant chr8:g.99440236C>A

# %%
from biothings_helper import Biothingsexplorer
explorer = Biothingsexplorer()
json_doc = explorer.get_json_doc('myvariant.info', 'chr8:g.99440236C>A')

# %%
# json doc with json-ld context added
json_doc
# Out:
# {'@context': {'cadd.gene.ccds_id': 'http://identifiers.org/ccds/',
#   'cadd.gene.feature_id': 'http://identifiers.org/ensembl.transcript/',
#   'cadd.gene.gene_id': 'http://identifiers.org/ensembl.gene/',
#   'cadd.gene.genename': 'http://identifiers.org/hgnc.symbol/',
#   'clinvar.gene.id': 'http://identifiers.org/hgnc/',
#   'clinvar.gene.symbol': 'http://identifiers.org/hgnc.symbol/',
#   'clinvar.omim': 'http://identifiers.org/omim/',
#   'clinvar.rcv.accession': 'http://identifers.org/clinvar/',
#   'clinvar.rcv.conditions.identifiers.efo': 'http://identifiers.org/efo/',
#   'clinvar.rcv.conditions.identifiers.omim': 'http://identifiers.org/omim/',
#   'clinvar.rcv.conditions.identifiers.orphanet': 'http://identifiers.org/orphanet/',
#   'clinvar.rsid': 'http://identifiers.org/dbsnp/',
#   'clinvar.uniprot': 'http://identifiers.org/uniprot/',
#   'dbnsfp.clinvar.rs': 'http://identifiers.org/dbsnp/',
#   'dbnsfp.ensembl.geneid': 'http://identifiers.org/ensembl.gene/',
#   'dbnsfp.ensembl.proteinid': 'http://identifiers.org/ensembl.protein/',
#   'dbnsfp.ensembl.transcriptid': 'http://identifiers.org/ensembl.transcript',
#   'dbnsfp.genename': 'http://identifiers.org/hgnc.symbol/',
#   'dbnsfp.rsid': 'http://identifiers.org/dbsnp/',
#   'dbnsfp.uniprot.acc': 'http://identifiers.org/uniprot/',
#   'dbsnp.gene.geneid': 'http://identifiers.org/hgnc/',
#   'dbsnp.gene.symbol': 'http://identifiers.org/hgnc.symbol/',
#   'dbsnp.rsid': 'http://identifiers.org/dbsnp/',
#   'docm.default_gene_name': 'http://identifiers.org/hgnc.symbol/',
#   'docm.ensembl_gene_id': 'http://identifiers.org/ensembl.gene/',
#   'docm.genename': 'http://identifiers.org/hgnc.symbol/',
#   'docm.pubmed_id': 'http://identifiers.org/pubmed/',
#   'emv.gene.id': 'http://identifiers.org/hgnc/',
#   'emv.gene.symbol': 'http://identifiers.org/hgnc.symbol/',
#   'evs.gene.accession': 'http://identifiers.org/refseq/',
#   'evs.gene.symbol': 'http://identifiers.org/hgnc.symbol/',
#   'evs.rsid': 'http://identifiers.org/dbsnp/',
#   'grasp.publication.snpid': 'http://identifiers.org/dbsnp/',
#   'grasp.rsid': 'http://identifiers.org/dbsnp/',
#   'gwassnps.genename': 'http://identifiers.org/hgnc.symbol/',
#   'gwassnps.pubmed': 'http://identifiers.org/pubmed/',
#   'gwassnps.rsid': 'http://identifiers.org/dbsnp/',
#   'mutdb.rsid': 'http://identifiers.org/dbsnp/',
#   'snpeff.ann.genename': 'http://identifiers.org/hgnc.symbol/',
#   'snpeff.lof.genename': 'http://identifiers.org/hgnc.symbol/',
#   'snpeff.nmd.genename': 'http://identifiers.org/hgnc.symbol/'},
#  '_id': 'chr8:g.99440236C>A',
#  '_version': 1,
#  'cadd._license': 'http://goo.gl/bkpNhq',
#  'cadd.alt': 'A',
#  'cadd.anc': 'C',
#  'cadd.annotype': 'CodingTranscript',
#  'cadd.bstatistic': 600,
#  'cadd.chmm.bivflnk': 0.063,
#  'cadd.chmm.enh': 0.0,
#  'cadd.chmm.enhbiv': 0.087,
#  'cadd.chmm.het': 0.016,
#  'cadd.chmm.quies': 0.039,
#  'cadd.chmm.reprpc': 0.528,
#  'cadd.chmm.reprpcwk': 0.094,
#  'cadd.chmm.tssa': 0.008,
#  'cadd.chmm.tssaflnk': 0.0,
#  'cadd.chmm.tssbiv': 0.11,
#  'cadd.chmm.tx': 0.0,
#  'cadd.chmm.txflnk': 0.0,
#  'cadd.chmm.txwk': 0.008,
#  'cadd.chmm.znfrpts': 0.008,
#  'cadd.chrom': 8,
#  'cadd.consdetail': 'stop_gained',
#  'cadd.consequence': 'STOP_GAINED',
#  'cadd.consscore': 8,
#  'cadd.cpg': 0.26,
#  'cadd.dna.helt': 0.71,
#  'cadd.dna.mgw': -0.26,
#  'cadd.dna.prot': -3.57,
#  'cadd.dna.roll': -1.14,
#  'cadd.encode.exp': 3.11,
#  'cadd.encode.h3k27ac': 1.0,
#  'cadd.encode.h3k4me1': 6.64,
#  'cadd.encode.h3k4me3': 6.0,
#  'cadd.encode.nucleo': 0.0,
#  'cadd.encode.occ': 4,
#  'cadd.encode.p_val.comb': 15.18,
#  'cadd.encode.p_val.ctcf': 11.8,
#  'cadd.encode.p_val.dnas': 15.4,
#  'cadd.encode.p_val.faire': 1.68,
#  'cadd.encode.p_val.mycp': 1.62,
#  'cadd.encode.p_val.polii': 0.0,
#  'cadd.encode.sig.ctcf': 1.96,
#  'cadd.encode.sig.dnase': 0.49,
#  'cadd.encode.sig.faire': 0.02,
#  'cadd.encode.sig.myc': 0.09,
#  'cadd.encode.sig.polii': 0.02,
#  'cadd.exon': '2/2',
#  'cadd.fitcons': 0.601731,
#  'cadd.gc': 0.71,
#  'cadd.gene.ccds_id': 'CCDS6279.1',
#  'cadd.gene.cds.cdna_pos': 379,
#  'cadd.gene.cds.cds_pos': 29,
#  'cadd.gene.cds.rel_cdna_pos': 0.07,
#  'cadd.gene.cds.rel_cds_pos': 0.02,
#  'cadd.gene.feature_id': 'ENST00000287042',
#  'cadd.gene.gene_id': 'ENSG00000156486',
#  'cadd.gene.genename': 'KCNS2',
#  'cadd.gene.prot.protpos': 10,
#  'cadd.gene.prot.rel_prot_pos': 0.02,
#  'cadd.gerp.n': 4.8,
#  'cadd.gerp.rs': 6739.9,
#  'cadd.gerp.rs_pval': 0,
#  'cadd.gerp.s': 3.91,
#  'cadd.isderived': 'TRUE',
#  'cadd.isknownvariant': 'FALSE',
#  'cadd.istv': 'TRUE',
#  'cadd.length': 0,
#  'cadd.mapability.20bp': 1,
#  'cadd.mapability.35bp': 1,
#  'cadd.min_dist_tse': 4141,
#  'cadd.min_dist_tss': 477,
#  'cadd.mutindex': 47,
#  'cadd.naa': '*',
#  'cadd.oaa': 'S',
#  'cadd.phast_cons.mammalian': 0.633,
#  'cadd.phast_cons.primate': 0.938,
#  'cadd.phast_cons.vertebrate': 0.913,
#  'cadd.phred': 35,
#  'cadd.phylop.mammalian': 1.222,
#  'cadd.phylop.primate': 0.552,
#  'cadd.phylop.vertebrate': 3.762,
#  'cadd.pos': 99440236,
#  'cadd.rawscore': 8.943177,
#  'cadd.ref': 'C',
#  'cadd.segway': 'TF0',
#  'cadd.tf.bs': 6,
#  'cadd.tf.bs_peaks': 7,
#  'cadd.tf.bs_peaks_max': 142.3577,
#  'cadd.type': 'SNV',
#  'chrom': '8',
#  'dbnsfp.aa.alt': 'X',
#  'dbnsfp.aa.codon_degeneracy': 0,
#  'dbnsfp.aa.codonpos': 2,
#  'dbnsfp.aa.pos': 10,
#  'dbnsfp.aa.ref': 'S',
#  'dbnsfp.aa.refcodon': 'TCG',
#  'dbnsfp.alt': 'A',
#  'dbnsfp.ancestral_allele': 'c',
#  'dbnsfp.cds_strand': '+',
#  'dbnsfp.chrom': '8',
#  'dbnsfp.dann._license': 'https://goo.gl/IeLhCq',
#  'dbnsfp.dann.rankscore': 0.56469,
#  'dbnsfp.dann.score': 0.9924952665873633,
#  'dbnsfp.eigen-pc.phred': 3.163276,
#  'dbnsfp.eigen-pc.raw': 0.195921368003061,
#  'dbnsfp.eigen-pc.raw_rankscore': 0.50005,
#  'dbnsfp.eigen.coding_or_noncoding': 'c',
#  'dbnsfp.eigen.phred': 4.558081,
#  'dbnsfp.eigen.raw': 0.433511512779213,
#  'dbnsfp.ensembl.geneid': 'ENSG00000156486',
#  'dbnsfp.ensembl.proteinid': ['ENSP00000287042', 'ENSP00000430712'],
#  'dbnsfp.ensembl.transcriptid': ['ENST00000287042', 'ENST00000521839'],
#  'dbnsfp.fathmm-mkl.coding_group': 'AEFDGBHCI',
#  'dbnsfp.fathmm-mkl.coding_pred': 'N',
#  'dbnsfp.fathmm-mkl.coding_rankscore': 0.24153,
#  'dbnsfp.fathmm-mkl.coding_score': 0.316,
#  'dbnsfp.fathmm.score': None,
#  'dbnsfp.genename': 'KCNS2',
#  'dbnsfp.genocanyon.rankscore': 0.74713,
#  'dbnsfp.genocanyon.score': 0.999999999971059,
#  'dbnsfp.gerp++.nr': 4.8,
#  'dbnsfp.gerp++.rs': 3.91,
#  'dbnsfp.gerp++.rs_rankscore': 0.44212,
#  'dbnsfp.gm12878.confidence_value': 0,
#  'dbnsfp.gm12878.fitcons_rankscore': 0.48707,
#  'dbnsfp.gm12878.fitcons_score': 0.596491,
#  'dbnsfp.h1-hesc.confidence_value': 2,
#  'dbnsfp.h1-hesc.fitcons_rankscore': 0.05288,
#  'dbnsfp.h1-hesc.fitcons_score': 0.378051,
#  'dbnsfp.hg18.end': 99509412,
#  'dbnsfp.hg18.start': 99509412,
#  'dbnsfp.hg19.end': 99440236,
#  'dbnsfp.hg19.start': 99440236,
#  'dbnsfp.hg38.end': 98428008,
#  'dbnsfp.hg38.start': 98428008,
#  'dbnsfp.huvec.confidence_value': 0,
#  'dbnsfp.huvec.fitcons_rankscore': 0.58052,
#  'dbnsfp.huvec.fitcons_score': 0.63947,
#  'dbnsfp.integrated.confidence_value': 0,
#  'dbnsfp.integrated.fitcons_rankscore': 0.33991,
#  'dbnsfp.integrated.fitcons_score': 0.59774,
#  'dbnsfp.lrt.converted_rankscore': 0.06324,
#  'dbnsfp.lrt.omega': 1.17275,
#  'dbnsfp.lrt.pred': 'N',
#  'dbnsfp.lrt.score': 0.723711,
#  'dbnsfp.m_cap_score.score': None,
#  'dbnsfp.metalr.score': None,
#  'dbnsfp.metasvm.score': None,
#  'dbnsfp.mutationassessor.score': None,
#  'dbnsfp.mutationtaster.AAE': ['S10*', 'S10*'],
#  'dbnsfp.mutationtaster.converted_rankscore': 0.81033,
#  'dbnsfp.mutationtaster.model': ['complex_aae', 'complex_aae'],
#  'dbnsfp.mutationtaster.pred': ['D', 'D'],
#  'dbnsfp.mutationtaster.score': [1, 1],
#  'dbnsfp.phastcons.100way.vertebrate': 0.04,
#  'dbnsfp.phastcons.100way.vertebrate_rankscore': 0.20781,
#  'dbnsfp.phastcons.20way.mammalian': 0.897,
#  'dbnsfp.phastcons.20way.mammalian_rankscore': 0.37868,
#  'dbnsfp.phylo.p100way.vertebrate': 2.054,
#  'dbnsfp.phylo.p100way.vertebrate_rankscore': 0.40723,
#  'dbnsfp.phylo.p20way.mammalian': 0.033,
#  'dbnsfp.phylo.p20way.mammalian_rankscore': 0.15068,
#  'dbnsfp.polyphen2._license': 'http://goo.gl/6Cz4Ae',
#  'dbnsfp.polyphen2.hdiv.score': None,
#  'dbnsfp.polyphen2.hvar.score': None,
#  'dbnsfp.provean.score': None,
#  'dbnsfp.ref': 'C',
#  'dbnsfp.rsid': 'rs777451821',
#  'dbnsfp.sift.score': None,
#  'dbnsfp.siphy_29way.logodds': 14.2027,
#  'dbnsfp.siphy_29way.logodds_rankscore': 0.65105,
#  'dbnsfp.siphy_29way.pi.a': 0.1507,
#  'dbnsfp.siphy_29way.pi.c': 0.8493,
#  'dbnsfp.siphy_29way.pi.g': 0.0,
#  'dbnsfp.siphy_29way.pi.t': 0.0,
#  'dbnsfp.vest3._license': 'http://goo.gl/jTko4F',
#  'dbnsfp.vest3.score': None,
#  'dbsnp.allele_origin': 'unspecified',
#  'dbsnp.alleles.allele': ['C', 'A', 'G'],
#  'dbsnp.alt': 'A',
#  'dbsnp.chrom': '8',
#  'dbsnp.class': 'SNV',
#  'dbsnp.dbsnp_build': 144,
#  'dbsnp.flags': ['ASP', 'NSM', 'NSN', 'REF'],
#  'dbsnp.gene.geneid': '3788',
#  'dbsnp.gene.symbol': 'KCNS2',
#  'dbsnp.hg19.end': 99440236,
#  'dbsnp.hg19.start': 99440236,
#  'dbsnp.ref': 'C',
#  'dbsnp.rsid': 'rs777451821',
#  'dbsnp.validated': False,
#  'dbsnp.var_subtype': 'unknown',
#  'dbsnp.vartype': 'snp',
#  'hg19.end': 99440236,
#  'hg19.start': 99440236,
#  'observed': True,
#  'snpeff.ann.cdna.length': '3166',
#  'snpeff.ann.cdna.position': '379',
#  'snpeff.ann.cds.length': '1434',
#  'snpeff.ann.cds.position': '29',
#  'snpeff.ann.effect': 'stop_gained',
#  'snpeff.ann.feature_id': 'NM_020697.2',
#  'snpeff.ann.feature_type': 'transcript',
#  'snpeff.ann.gene_id': 'KCNS2',
#  'snpeff.ann.genename': 'KCNS2',
#  'snpeff.ann.hgvs_c': 'c.29C>A',
#  'snpeff.ann.hgvs_p': 'p.Ser10*',
#  'snpeff.ann.protein.length': '477',
#  'snpeff.ann.protein.position': '10',
#  'snpeff.ann.putative_impact': 'HIGH',
#  'snpeff.ann.rank': '2',
#  'snpeff.ann.total': '2',
#  'snpeff.ann.transcript_biotype': 'Coding',
#  'vcf.alt': 'A',
#  'vcf.position': '99440236',
#  'vcf.ref': 'C'}

# %% [markdown]
# #### Step 2: List all available apis linked from this variant

# %%
explorer.find_linked_apis()
# Out:
# Available APIs which could be linked out is: {'mygene.info': 'ENSG00000156486'}

# %% [markdown]
# #### Step 3: Link to mygene.info and get interpro ID

# %%
explorer.explore_api('mygene.info', fields_uri='http://identifiers.org/interpro/')
# Out:
# {'_id': '3788',
#  '_score': 22.792553,
#  'interpro': [{'id': 'IPR011333'},
#   {'id': 'IPR000210'},
#   {'id': 'IPR005821'},
#   {'id': 'IPR027359'},
#   {'id': 'IPR003968'},
#   {'id': 'IPR028325'},
#   {'id': 'IPR003131'},
#   {'id': 'IPR003971'}]}
